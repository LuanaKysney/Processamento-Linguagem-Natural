# %% [markdown]
# # Exercício 2 - N-Gramas

# %% [markdown]
# Neste exercício, vamos construir um modelo linguístico baseados em n-gramas. Para criarmos esse modelo, usaremos a frequência relativa para calcular a probabilidade de uma palavra aparecer dado uma sequência de palavras. Com o modelo, vamos gerar um texto baseado no corpus de treinamento.

# %%
from nltk.corpus import machado
from nltk.util import bigrams, trigrams, ngrams
from collections import Counter
import pandas as pd
import random
import nltk
nltk.download('machado')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package machado to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# Vamos utilizar um corpus em português para gerar nosso modelo. Vamos carregar, a partir do corpus Machado do NLTK, o texto Memórias Póstumas de Brás Cubas. Vamos carregar uma lista de sentenças tokenizadas.

# %%
corpus = machado.sents('romance/marm05.txt')
corpus[:100]
# Out:
# [['Romance', ',', 'Memórias', 'Póstumas', 'de', 'Brás', 'Cubas', ',', '1880'], ['Memórias', 'Póstumas', 'de', 'Brás', 'Cubas'], ...]

# %% [markdown]
# Para gerar o modelo corretamente, precisamos demarcar onde a sentença começa e onde termina. Vamos adicionar tokens de início e fim de sentença. Vamos criar um modelo de trigrama, assim, o primeiro trigrama precisa demarcar a primeira palavra da sentença. Por isso, adicionamos dois tokens de início em cada sentença e um de fim no final. Aqui também convertemos a nossa lista de sentenças em uma lista de palaveras.

# %%
words = []
for sent in corpus:
    sent.insert(0, '<s>')
    sent.insert(0, '<s>')
    sent.append('</s>')
    words.extend(sent)

# %% [markdown]
# Vamos agora gerar as trigramas e bigramas necessárias para o modelo. Para isso, usamos a função bigrams e trigrams do pacote NLTK que facilita nosso trabalho. A função funciona a partir de listas de palavras previamente segmentadas.

# %%
words_bigram = bigrams(words)
words_trigram = trigrams(words)

# %% [markdown]
# Vamos contar os bigramas, para isso vamos usar o Counter.

# %%
count_bigram = Counter(words_bigram)
count_bigram
# Out:
# Counter({('<s>', '<s>'): 3822,
#          ('<s>', 'Romance'): 1,
#          ('Romance', ','): 1,
#          (',', 'Memórias'): 1,
#          ('Memórias', 'Póstumas'): 5,
#          ('Póstumas', 'de'): 4,
#          ('de', 'Brás'): 6,
#          ('Brás', 'Cubas'): 29,
#          ('Cubas', ','): 16,
#          (',', '1880'): 1,
#          ('1880', '</s>'): 1,
#          ('</s>', '<s>'): 3821,
#          ('<s>', 'Memórias'): 1,
#          ('Cubas', '</s>'): 1,
#          ('<s>', 'Texto'): 1,
#          ('Texto', '-'): 1,
#          ('-', 'fonte'): 1,
#          ('fonte', ':'): 1,
#          (':', 'Obra'): 1,
#          ('Obra', 'Completa'): 1,
#          ('Completa', ','): 1,
#          (',', 'Machado'): 1,
#          ('Machado', 'de'): 2,
#          ('de', 'Assis'): 2,
#          ('Assis', ','): 1,
#          (',', 'Rio'): 1,
#          ('Rio', 'de'): 8,
#          ('de', 'Janeiro'): 8,
#          ('Janeiro', ':'): 1,
#          (':', 'Editora'): 1,
#          ('Editora', 'Nova'): 1,
#          ('Nova', 'Aguilar'): 1,
#          ('Aguilar', ','): 1,
#          (',', '1994'): 1,
#          ('1994', '.'): 1,
#          ('.', '</s>'): 2813,
#          ('<s>', 'Publicado'): 1,
#          ('Publicado', 'originalmente'): 1,
#          ('originalmente', 'em'): 1,
#          ('em', 'folhetins'): 1,
#          ('folhetins', ','): 1,
#          (',', 'a'): 273,
#          ('a', 'partir'): 1,
#          ('partir', 'de'): 1,
#          ('de', 'março'): 2,
#          ('março', 'de'): 1,
#          ('de', '1880'): 2,
#          ('1880', ','): 1,
#          (',', 'na'): 37,
#          ('na', 'Revista'): 2,
#          ('Revista', 'Brasileira'): 2,
#          ('Brasileira', '.'): 1,
#          ('<s>', 'Ao'): 33,
#          ('Ao', 'verme'): 1,
#          ('verme', 'que'): 1,
#          ('que', 'primeiro'): 2,
#          ('primeiro', 'roeu'): 1,
#          ('roeu', 'as'): 1,
#          ('as', 'frias'): 1,
#          ('frias', 'carnes'): 1,
#          ('carnes', 'do'): 1,
#          ('do', 'meu'): 29,
#          ('meu', 'cadáver'): 1,
#          ('cadáver', '</s>'): 1,
#          ('<s>', 'dedico'): 1,
#          ('dedico', 'como'): 1,
#          ('como', 'saudosa'): 1,
#          ('saudosa', 'lembrança'): 1,
#          ('lembrança', '</s>'): 1,
#          ('<s>', 'estas'): 1,
#          ('estas', 'Memórias'): 1,
#          ('Póstumas', '</s>'): 1,
#          ('<s>', 'Prólogo'): 1,
#          ('Prólogo', 'da'): 1,
#          ('da', 'terceira'): 1,
#          ('terceira', 'edição'): 2,
#          ('edição', '</s>'): 1,
#          ('<s>', 'A'): 125,
#          ('A', 'primeira'): 2,
#          ('primeira', 'edição'): 2,
#          ('edição', 'destas'): 1,
#          ('destas', 'Memórias'): 2,
#          ('Cubas', 'foi'): 1,
#          ('foi', 'feita'): 1,
#          ('feita', 'aos'): 1,
#          ('aos', 'pedaços'): 1,
#          ('pedaços', 'na'): 1,
#          ('Brasileira', ','): 1,
#          (',', 'pelos'): 2,
#          ('pelos', 'anos'): 1,
#          ('anos', 'de'): 3,
#          ('1880', '.'): 1,
#          ('<s>', 'Postas'): 1,
#          ('Postas', 'mais'): 1,
#          ('mais', 'tarde'): 8,
#          ('tarde', 'em'): 1,
#          ('em', 'livro'): 1,
#          ('livro', ','): 11,
#          (',', 'corrigi'): 2,
#          ('corrigi', 'o'): 1,
#          ('o', 'texto'): 1,
#          ('texto', 'em'): 1,
#          ('em', 'vários'): 1,
#          ('vários', 'lugares'): 1,
#          ('lugares', '.'): 2,
#          ('<s>', 'Agora'): 18,
#          ('Agora', 'que'): 1,
#          ('que', 'tive'): 2,
#          ('tive', 'de'): 1,
#          ('de', 'o'): 12,
#          ('o', 'rever'): 1,
#          ('rever', 'para'): 1,
#          ('para', 'a'): 42,
#          ('a', 'terceira'): 4,
#          ('edição', ','): 3,
#          (',', 'emendei'): 1,
#          ('emendei', 'ainda'): 1,
#          ('ainda', 'alguma'): 1,
#          ('alguma', 'coisa'): 44,
#          ('coisa', 'e'): 2,
#          ('e', 'suprimi'): 1,
#          ('suprimi', 'duas'): 1,
#          ('duas', 'ou'): 5,
#          ('ou', 'três'): 7,
#          ('três', 'dúzias'): 1,
#          ('dúzias', 'de'): 2,
#          ('de', 'linhas'): 1,
#          ('linhas', '.'): 1,
#          ('<s>', 'Assim'): 12,
#          ('Assim', 'composta'): 1,
#          ('composta', ','): 1,
#          (',', 'sai'): 1,
#          ('sai', 'novamente'): 1,
#          ('novamente', 'à'): 1,
#          ('à', 'luz'): 5,
#          ('luz', 'esta'): 1,
#          ('esta', 'obra'): 1,
#          ('obra', 'que'): 1,
#          ('que', 'alguma'): 1,
#          ('alguma', 'benevolência'): 1,
#          ('benevolência', 'parece'): 1,
#          ('parece', 'ter'): 1,
#          ('ter', 'encontrado'): 1,
#          ('encontrado', 'no'): 1,
#          ('no', 'público'): 1,
#          ('público', '.'): 2,
#          ('<s>', 'Capistrano'): 1,
#          ('Capistrano', 'de'): 1,
#          ('de', 'Abreu'): 1,
#          ('Abreu', ','): 1,
#          (',', 'noticiando'): 1,
#          ('noticiando', 'a'): 1,
#          ('a', 'publicação'): 3,
#          ('publicação', 'do'): 1,
#          ('do', 'livro'): 8,
#          (',', 'perguntava'): 3,
#          ('perguntava', ':'): 1,
#          (':', '\x93'): 9,
#          ('\x93', 'As'): 1,
#          ('As', 'Memórias'): 1,
#          ('Cubas', 'são'): 1,
#          ('são', 'um'): 2,
#          ('um', 'romance'): 1,
#          ('romance', '?\x94'): 1,
#          ('?\x94', 'Macedo'): 1,
#          ('Macedo', 'Soares'): 1,
#          ('Soares', ','): 1,
#          (',', 'em'): 62,
#          ('em', 'carta'): 1,
#          ('carta', 'que'): 1,
#          ('que', 'me'): 121,
#          ('me', 'escreveu'): 1,
#          ('escreveu', 'por'): 1,
#          ('por', 'esse'): 8,
#          ('esse', 'tempo'): 11,
#          ('tempo', ','): 36,
#          (',', 'recordava'): 1,
#          ('recordava', 'amigamente'): 1,
#          ('amigamente', 'as'): 1,
#          ('as', 'Viagens'): 1,
#          ('Viagens', 'na'): 1,
#          ('na', 'minha'): 17,
#          ('minha', 'terra'): 1,
#          ('terra', '.'): 1,
#          ('Ao', 'primeiro'): 1,
#          ('primeiro', 'respondia'): 1,
#          ('respondia', 'já'): 1,
#          ('já', 'o'): 2,
#          ('o', 'defunto'): 2,
#          ('defunto', 'Brás'): 1,
#          ('Cubas', '('): 1,
#          ('(', 'como'): 2,
#          ('como', 'o'): 23,
#          ('o', 'leitor'): 19,
#          ('leitor', 'viu'): 1,
#          ('viu', 'e'): 1,
#          ('e', 'verá'): 2,
#          ('verá', 'no'): 1,
#          ('no', 'prólogo'): 1,
#          ('prólogo', 'dele'): 1,
#          ('dele', 'que'): 1,
#          ('que', 'vai'): 3,
#          ('vai', 'adiante'): 1,
#          ('adiante', ')'): 1,
#          (')', 'que'): 4,
#          ('que', 'sim'): 11,
#          ('sim', 'e'): 1,
#          ('e', 'que'): 32,
#          ('que', 'não'): 143,
#          ('não', ','): 13,
#          (',', 'que'): 446,
#          ('que', 'era'): 85,
#          ('era', 'romance'): 1,
#          ('romance', 'para'): 1,
#          ('para', 'uns'): 1,
#          ('uns', 'e'): 1,
#          ('e', 'não'): 73,
#          ('não', 'o'): 6,
#          ('o', 'era'): 3,
#          ('era', 'para'): 3,
#          ('para', 'outros'): 1,
#          ('outros', '.'): 10,
#          ('<s>', 'Quanto'): 16,
#          ('Quanto', 'ao'): 4,
#          ('ao', 'segundo'): 1,
#          ('segundo', ','): 2,
#          (',', 'assim'): 8,
#          ('assim', 'se'): 1,
#          ('se', 'explicou'): 1,
#          ('explicou', 'o'): 1,
#          ('o', 'finado'): 1,
#          ('finado', ':'): 1,
#          ('\x93', 'Trata'): 1,
#          ('Trata', '-'): 3,
#          ('-', 'se'): 287,
#          ('se', 'de'): 13,
#          ('de', 'uma'): 110,
#          ('uma', 'obra'): 3,
#          ('obra', 'difusa'): 2,
#          ('difusa', ','): 2,
#          ('na', 'qual'): 3,
#          ('qual', 'eu'): 3,
#          ('eu', ','): 38,
#          (',', 'Brás'): 7,
#          (',', 'se'): 105,
#          ('se', 'adotei'): 2,
#          ('adotei', 'a'): 2,
#          ('a', 'forma'): 4,
#          ('forma', 'livre'): 2,
#          ('livre', 'de'): 3,
#          ('de', 'um'): 156,
#          ('um', 'Sterne'): 2,
#          ('Sterne', 'ou'): 1,
#          ('ou', 'de'): 11,
#          ('um', 'Xavier'): 2,
#          ('Xavier', 'de'): 3,
#          ('de', 'Maistre'): 3,
#          ('Maistre', ','): 2,
#          (',', 'não'): 176,
#          ('não', 'sei'): 37,
#          ('sei', 'se'): 23,
#          ('se', 'lhe'): 11,
#          ('lhe', 'meti'): 2,
#          ('meti', 'algumas'): 2,
#          ('algumas', 'rabugens'): 2,
#          ('rabugens', 'de'): 3,
#          ('de', 'pessimismo'): 3,
#          ('pessimismo', '.\x94'): 1,
#          ('.\x94', 'Toda'): 1,
#          ('Toda', 'essa'): 1,
#          ('essa', 'gente'): 1,
#          ('gente', 'viajou'): 1,
#          ('viajou', ':'): 1,
#          (':', 'Xavier'): 1,
#          ('Maistre', 'à'): 1,
#          ('à', 'roda'): 5,
#          ('roda', 'do'): 2,
#          ('do', 'quarto'): 3,
#          ('quarto', ','): 2,
#          (',', 'Garret'): 1,
#          ('Garret', 'na'): 1,
#          ('na', 'terra'): 2,
#          ('terra', 'dele'): 1,
#          ('dele', ','): 15,
#          (',', 'Sterne'): 1,
#          ('Sterne', 'na'): 1,
#          ('terra', 'dos'): 1,
#          ('dos', 'outros'): 12,
#          ('<s>', 'De'): 31,
#          ('De', 'Brás'): 1,
#          ('Cubas', 'se'): 1,
#          ('se', 'pode'): 5,
#          ('pode', 'dizer'): 2,
#          ('dizer', 'que'): 20,
#          ('que', 'viajou'): 1,
#          ('viajou', 'à'): 1,
#          ('roda', 'da'): 1,
#          ('da', 'vida'): 34,
#          ('vida', '.'): 12,
#          ('<s>', 'O'): 110,
#          ('O', 'que'): 15,
#          ('que', 'faz'): 7,
#          ('faz', 'do'): 1,
#          ('meu', 'Brás'): 1,
#          ('Cubas', 'um'): 1,
#          ('um', 'autor'): 2,
#          ('autor', 'particular'): 1,
#          ('particular', 'é'): 1,
#          ('é', 'o'): 36,
#          ('o', 'que'): 104,
#          ('que', 'ele'): 54,
#          ('ele', 'chama'): 1,
#          ('chama', '\x93'): 1,
#          ('\x93', 'rabugens'): 1,
#          ('pessimismo', '\x94.'): 1,
#          ('\x94.', '</s>'): 12,
#          ('<s>', 'Há'): 9,
#          ('Há', 'na'): 1,
#          ('na', 'alma'): 1,
#          ('alma', 'deste'): 1,
#          ('deste', 'livro'): 7,
#          (',', 'por'): 61,
#          ('por', 'mais'): 3,
#          ('mais', 'risonho'): 1,
#          ('risonho', 'que'): 1,
#          ('que', 'pareça'): 1,
#          ('pareça', ','): 1,
#          (',', 'um'): 114,
#          ('um', 'sentimento'): 5,
#          ('sentimento', 'amargo'): 1,
#          ('amargo', 'e'): 2,
#          ('e', 'áspero'): 1,
#          ('áspero', ','): 2,
#          ('que', 'está'): 4,
#          ('está', 'longe'): 1,
#          ('longe', 'de'): 7,
#          ('de', 'vir'): 5,
#          ('vir', 'de'): 1,
#          ('de', 'seus'): 5,
#          ('seus', 'modelos'): 1,
#          ('modelos', '.'): 1,
#          ('<s>', 'É'): 17,
#          ('É', 'taça'): 1,
#          ('taça', 'que'): 1,
#          ('que', 'pode'): 2,
#          ('pode', 'ter'): 1,
#          ('ter', 'lavores'): 1,
#          ('lavores', 'de'): 1,
#          ('de', 'igual'): 2,
#          ('igual', 'escola'): 1,
#          ('escola', ','): 6,
#          (',', 'mas'): 159,
#          ('mas', 'leva'): 1,
#          ('leva', 'outro'): 1,
#          ('outro', 'vinho'): 1,
#          ('vinho', '.'): 2,
#          ('<s>', 'Não'): 185,
#          ('Não', 'digo'): 10,
#          ('digo', 'mais'): 4,
#          ('mais', 'para'): 2,
#          ('para', 'não'): 6,
#          ('não', 'entrar'): 1,
#          ('entrar', 'na'): 3,
#          ('na', 'crítica'): 1,
#          ('crítica', 'de'): 1,
#          ('um', 'defunto'): 4,
#          ('defunto', ','): 3,
#          ('que', 'se'): 63,
#          ('se', 'pintou'): 1,
#          ('pintou', 'a'): 1,
#          ('a', 'si'): 12,
#          ('si', 'e'): 2,
#          ('e', 'a'): 103,
#          ('a', 'outros'): 2,
#          ('outros', ','): 12,
#          (',', 'conforme'): 2,
#          ('conforme', 'lhe'): 1,
#          ('lhe', 'pareceu'): 1,
#          ('pareceu', 'melhor'): 1,
#          ('melhor', 'e'): 1,
#          ('e', 'mais'): 11,
#          ('mais', 'certo'): 1,
#          ('certo', '.'): 2,
#          ('<s>', 'Machado'): 1,
#          ('Assis', '.'): 1,
#          ('<s>', 'AO'): 1,
#          ('AO', 'LEITOR'): 1,
#          ('LEITOR', '</s>'): 1,
#          ('<s>', 'Que'): 39,
#          ('Que', 'Stendhal'): 1,
#          ('Stendhal', 'confessasse'): 1,
#          ('confessasse', 'haver'): 1,
#          ('haver', 'escrito'): 1,
#          ('escrito', 'um'): 1,
#          ('um', 'de'): 3,
#          ('seus', 'livros'): 2,
#          ('livros', 'para'): 1,
#          ('para', 'cem'): 1,
#          ('cem', 'leitores'): 2,
#          ('leitores', ','): 2,
#          (',', 'coisa'): 7,
#          ('coisa', 'é'): 7,
#          ('é', 'que'): 89,
#          ('que', 'admira'): 1,
#          ('admira', 'e'): 1,
#          ('e', 'consterna'): 1,
#          ('consterna', '.'): 1,
#          ('não', 'admira'): 2,
#          ('admira', ','): 1,
#          (',', 'nem'): 82,
#          ('nem', 'provavelmente'): 1,
#          ('provavelmente', 'consternará'): 1,
#          ('consternará', 'é'): 1,
#          ('é', 'se'): 2,
#          ('se', 'este'): 2,
#          ('este', 'outro'): 3,
#          ('outro', 'livro'): 1,
#          ('livro', 'não'): 1,
#          ('não', 'tiver'): 1,
#          ('tiver', 'os'): 1,
#          ('os', 'cem'): 1,
#          ('leitores', 'de'): 1,
#          ('de', 'Stendhal'): 2,
#          ('Stendhal', ','): 2,
#          ('nem', 'cinqüenta'): 1,
#          ('cinqüenta', ','): 2,
#          ('nem', 'vinte'): 1,
#          ('vinte', 'e'): 4,
#          ('e', ','): 49,
#          (',', 'quando'): 55,
#          ('quando', 'muito'): 3,
#          ('muito', ','): 25,
#          (',', 'dez'): 1,
#          ('dez', '.'): 1,
#          ('<s>', 'Dez'): 1,
#          ('Dez', '?'): 1,
#          ('?', '</s>'): 262,
#          ('<s>', 'Talvez'): 30,
#          ('Talvez', 'cinco'): 2,
#          ('cinco', '.'): 1,
#          ('<s>', 'Trata'): 3,
#          ('se', ','): 36,
#          ('na', 'verdade'): 4,
#          ('verdade', ','): 26,
#          (',', 'de'): 97,
#          ('Sterne', ','): 1,
#          (',', 'ou'): 67,
#          ('pessimismo', '.'): 1,
#          ('<s>', 'Pode'): 1,
#          ('Pode', 'ser'): 3,
#          ('ser', '.'): 4,
#          ('<s>', 'Obra'): 1,
#          ('Obra', 'de'): 1,
#          ('de', 'finado'): 1,
#          ('finado', '.'): 1,
#          ('<s>', 'Escrevi'): 2,
#          ('Escrevi', '-'): 1,
#          ('-', 'a'): 100,
#          ('a', 'com'): 10,
#          ('com', 'a'): 87,
#          ('a', 'pena'): 11,
#          ('pena', 'da'): 1,
#          ('da', 'galhofa'): 1,
#          ('galhofa', 'e'): 1,
#          ('a', 'tinta'): 1,
#          ('tinta', 'da'): 1,
#          ('da', 'melancolia'): 3,
#          ('melancolia', ','): 2,
#          (',', 'e'): 727,
#          ('não', 'é'): 45,
#          ('é', 'difícil'): 1,
#          ('difícil', 'antever'): 1,
#          ('antever', 'o'): 1,
#          ('que', 'poderá'): 1,
#          ('poderá', 'sair'): 1,
#          ('sair', 'desse'): 1,
#          ('desse', 'conúbio'): 1,
#          ('conúbio', '.'): 1,
#          ('<s>', 'Acresce'): 3,
#          ('Acresce', 'que'): 3,
#          ('que', 'a'): 132,
#          ('a', 'gente'): 10,
#          ('gente', 'grave'): 1,
#          ('grave', 'achará'): 1,
#          ('achará', 'no'): 1,
#          ('no', 'livro'): 2,
#          ('livro', 'umas'): 1,
#          ('umas', 'aparências'): 1,
#          ('aparências', 'de'): 1,
#          ('de', 'puro'): 1,
#          ('puro', 'romance'): 1,
#          ('romance', ','): 2,
#          (',', 'ao'): 75,
#          ('ao', 'passo'): 10,
#          ('passo', 'que'): 12,
#          ('gente', 'frívola'): 1,
#          ('frívola', 'não'): 1,
#          ('não', 'achará'): 1,
#          ('achará', 'nele'): 1,
#          ('nele', 'o'): 2,
#          ('o', 'seu'): 28,
#          ('seu', 'romance'): 1,
#          ('romance', 'usual'): 1,
#          ('usual', ';'): 1,
#          (';', 'ei'): 2,
#          ('ei', '-'): 4,
#          ('-', 'lo'): 77,
#          ('lo', 'aí'): 1,
#          ('aí', 'fica'): 3,
#          ('fica', 'privado'): 1,
#          ('privado', 'da'): 1,
#          ('da', 'estima'): 1,
#          ('estima', 'dos'): 1,
#          ('dos', 'graves'): 1,
#          ('graves', 'e'): 1,
#          ('e', 'do'): 24,
#          ('do', 'amor'): 6,
#          ('amor', 'dos'): 1,
#          ('dos', 'frívolos'): 1,
#          ('frívolos', ','): 1,
#          ('que', 'são'): 2,
#          ('são', 'as'): 3,
#          ('as', 'duas'): 5,
#          ('duas', 'colunas'): 1,
#          ('colunas', 'máximas'): 1,
#          ('máximas', 'da'): 1,
#          ('da', 'opinião'): 7,
#          ('opinião', '.'): 2,
#          ('<s>', 'Mas'): 68,
#          ('Mas', 'eu'): 10,
#          ('eu', 'ainda'): 2,
#          ('ainda', 'espero'): 1,
#          ('espero', 'angariar'): 1,
#          ('angariar', 'as'): 1,
#          ('as', 'simpatias'): 1,
#          ('simpatias', 'da'): 1,
#          ('opinião', ','): 10,
#          ('e', 'o'): 78,
#          ('o', 'primeiro'): 14,
#          ('primeiro', 'remédio'): 1,
#          ('remédio', 'é'): 1,
#          ('é', 'fugir'): 1,
#          ('fugir', 'a'): 2,
#          ('a', 'um'): 39,
#          ('um', 'prólogo'): 1,
#          ('prólogo', 'explícito'): 1,
#          ('explícito', 'e'): 1,
#          ('e', 'longo'): 3,
#          ('longo', '.'): 3,
#          ('O', 'melhor'): 5,
#          ('melhor', 'prólogo'): 1,
#          ('prólogo', 'é'): 1,
#          ('que', 'contém'): 1,
#          ('contém', 'menos'): 1,
#          ('menos', 'coisas'): 1,
#          ('coisas', ','): 15,
#          ('ou', 'o'): 6,
#          ('que', 'as'): 17,
#          ('as', 'diz'): 1,
#          ('diz', 'de'): 1,
#          ('um', 'jeito'): 4,
#          ('jeito', 'obscuro'): 1,
#          ('obscuro', 'e'): 2,
#          ('e', 'truncado'): 1,
#          ('truncado', '.'): 1,
#          ('<s>', 'Conseguintemente'): 1,
#          ('Conseguintemente', ','): 1,
#          (',', 'evito'): 1,
#          ('evito', 'contar'): 1,
#          ('contar', 'o'): 1,
#          ('o', 'processo'): 1,
#          ('processo', 'extraordinário'): 1,
#          ('extraordinário', 'que'): 1,
#          ('que', 'empreguei'): 1,
#          ('empreguei', 'na'): 1,
#          ('na', 'composição'): 1,
#          ('composição', 'destas'): 1,
#          ('Memórias', ','): 1,
#          (',', 'trabalhadas'): 1,
#          ('trabalhadas', 'cá'): 1,
#          ('cá', 'no'): 1,
#          ('no', 'outro'): 3,
#          ('outro', 'mundo'): 1,
#          ('mundo', '.'): 3,
#          ('<s>', 'Seria'): 3,
#          ('Seria', 'curioso'): 1,
#          ('curioso', ','): 1,
#          ('mas', 'nimiamente'): 1,
#          ('nimiamente', 'extenso'): 1,
#          ('extenso', ','): 1,
#          ('e', 'aliás'): 5,
#          ('aliás', 'desnecessário'): 1,
#          ('desnecessário', 'ao'): 1,
#          ('ao', 'entendimento'): 1,
#          ('entendimento', 'da'): 1,
#          ('da', 'obra'): 1,
#          ('obra', '.'): 2,
#          ('A', 'obra'): 1,
#          ('obra', 'em'): 1,
#          ('em', 'si'): 8,
#          ('si', 'mesma'): 13,
#          ('mesma', 'é'): 1,
#          ('é', 'tudo'): 1,
#          ('tudo', ':'): 3,
#          (':', 'se'): 1,
#          ('se', 'te'): 5,
#          ('te', 'agradar'): 1,
#          ('agradar', ','): 2,
#          (',', 'fino'): 2,
#          ('fino', 'leitor'): 1,
#          ('leitor', ','): 8,
#          (',', 'pago'): 2,
#          ('pago', '-'): 2,
#          ('-', 'me'): 605,
#          ('me', 'da'): 9,
#          ('da', 'tarefa'): 1,
#          ('tarefa', ';'): 1,
#          (';', 'se'): 12,
#          ('te', 'não'): 5,
#          ('não', 'agradar'): 1,
#          ('-', 'te'): 26,
#          ('te', 'com'): 5,
#          ('com', 'um'): 50,
#          ('um', 'piparote'): 3,
#          ('piparote', ','): 1,
#          ('e', 'adeus'): 1,
#          ('adeus', '.'): 1,
#          ('<s>', 'Brás'): 1,
#          ('Cubas', '.'): 8,
#          ('<s>', 'CAPÍTULO'): 160,
#          ('CAPÍTULO', 'PRIMEIRO'): 1,
#          ('PRIMEIRO', '/'): 1,
#          ('/', 'ÓBITO'): 1,
#          ('ÓBITO', 'DO'): 1,
#          ('DO', 'AUTOR'): 1,
#          ('AUTOR', '</s>'): 1,
#          ('<s>', 'Algum'): 3,
#          ('Algum', 'tempo'): 2,
#          ('tempo', 'hesitei'): 1,
#          ('hesitei', 'se'): 1,
#          ('se', 'devia'): 1,
#          ('devia', 'abrir'): 1,
#          ('abrir', 'estas'): 1,
#          ('estas', 'memórias'): 1,
#          ('memórias', 'pelo'): 1,
#          ('pelo', 'princípio'): 1,
#          ('princípio', 'ou'): 1,
#          ('ou', 'pelo'): 1,
#          ('pelo', 'fim'): 1,
#          ('fim', ','): 4,
#          (',', 'isto'): 11,
#          ('isto', 'é'): 14,
#          ('é', ','): 12,
#          ('se', 'poria'): 1,
#          ('poria', 'em'): 1,
#          ('em', 'primeiro'): 1,
#          ('primeiro', 'lugar'): 2,
#          ('lugar', 'o'): 1,
#          ('o', 'meu'): 47,
#          ('meu', 'nascimento'): 1,
#          ('nascimento', 'ou'): 1,
#          ('ou', 'a'): 6,
#          ('a', 'minha'): 62,
#          ('minha', 'morte'): 2,
#          ('morte', '.'): 8,
#          ('<s>', 'Suposto'): 1,
#          ('Suposto', 'o'): 1,
#          ('o', 'uso'): 4,
#          ('uso', 'vulgar'): 1,
#          ('vulgar', 'seja'): 1,
#          ('seja', 'começar'): 1,
#          ('começar', 'pelo'): 1,
#          ('pelo', 'nascimento'): 1,
#          ('nascimento', ','): 1,
#          (',', 'duas'): 3,
#          ('duas', 'considerações'): 1,
#          ('considerações', 'me'): 1,
#          ('me', 'levaram'): 2,
#          ('levaram', 'a'): 1,
#          ('a', 'adotar'): 1,
#          ('adotar', 'diferente'): 1,
#          ('diferente', 'método'): 1,
#          ('método', ':'): 1,
#          (':', 'a'): 10,
#          ('a', 'primeira'): 16,
#          ('primeira', 'é'): 1,
#          ('que', 'eu'): 112,
#          ('eu', 'não'): 39,
#          ('não', 'sou'): 5,
#          ('sou', 'propriamente'): 1,
#          ('propriamente', 'um'): 1,
#          ('autor', 'defunto'): 1,
#          ('mas', 'um'): 10,
#          ('defunto', 'autor'): 1,
#          ('autor', ','): 1,
#          (',', 'para'): 52,
#          ('para', 'quem'): 3,
#          ('quem', 'a'): 1,
#          ('a', 'campa'): 1,
#          ('campa', 'foi'): 1,
#          ('foi', 'outro'): 2,
#          ('outro', 'berço'): 1,
#          ('berço', ';'): 1,
#          (';', 'a'): 51,
#          ('a', 'segunda'): 6,
#          ('segunda', 'é'): 1,
#          ('que', 'o'): 128,
#          ('o', 'escrito'): 1,
#          ('escrito', 'ficaria'): 1,
#          ('ficaria', 'assim'): 1,
#          ('assim', 'mais'): 1,
#          ('mais', 'galante'): 1,
#          ('galante', 'e'): 1,
#          ('mais', 'novo'): 1,
#          ('novo', '.'): 3,
#          ('<s>', 'Moisés'): 1,
#          ('Moisés', ','): 1,
#          ('que', 'também'): 6,
#          ('também', 'contou'): 1,
#          ('contou', 'a'): 1,
#          ('a', 'sua'): 26,
#          ('sua', 'morte'): 1,
#          ('morte', ','): 17,
#          ('não', 'a'): 10,
#          ('a', 'pôs'): 1,
#          ('pôs', 'no'): 2,
#          ('no', 'intróito'): 1,
#          ('intróito', ','): 1,
#          ('mas', 'no'): 4,
#          ('no', 'cabo'): 1,
#          ('cabo', ':'): 1,
#          (':', 'diferença'): 1,
#          ('diferença', 'radical'): 1,
#          ('radical', 'entre'): 1,
#          ('entre', 'este'): 1,
#          ('este', 'livro'): 5,
#          ('livro', 'e'): 4,
#          ('o', 'Pentateuco'): 1,
#          ('Pentateuco', '.'): 1,
#          ('<s>', 'Dito'): 3,
#          ('Dito', 'isto'): 2,
#          ('isto', ','): 9,
#          (',', 'expirei'): 1,
#          ('expirei', 'às'): 1,
#          ('às', 'duas'): 1,
#          ('duas', 'horas'): 5,
#          ('horas', 'da'): 4,
#          ('da', 'tarde'): 7,
#          ('tarde', 'de'): 2,
#          ('uma', 'sexta'): 1,
#          ('sexta', '-'): 2,
#          ('-', 'feira'): 4,
#          ('feira', 'do'): 1,
#          ('do', 'mês'): 1,
#          ('mês', 'de'): 1,
#          ('de', 'agosto'): 1,
#          ('agosto', 'de'): 1,
#          ('de', '1869'): 1,
#          ('1869', ','): 1,
#          ('minha', 'bela'): 1,
#          ('bela', 'chácara'): 1,
#          ('chácara', 'de'): 1,
#          ('de', 'Catumbi'): 1,
#          ('Catumbi', '.'): 1,
#          ('<s>', 'Tinha'): 18,
#          ('Tinha', 'uns'): 1,
#          ('uns', 'sessenta'): 1,
#          ('sessenta', 'e'): 2,
#          ('e', 'quatro'): 4,
#          ('quatro', 'anos'): 3,
#          ('anos', ','): 28,
#          (',', 'rijos'): 1,
#          ('rijos', 'e'): 1,
#          ('e', 'prósperos'): 1,
#          ('prósperos', ','): 1,
#          (',', 'era'): 53,
#          ('era', 'solteiro'): 1,
#          ('solteiro', ','): 2,
#          (',', 'possuía'): 3,
#          ('possuía', 'cerca'): 1,
#          ('cerca', 'de'): 2,
#          ('de', 'trezentos'): 2,
#          ('trezentos', 'contos'): 1,
#          ('contos', 'e'): 1,
#          ('e', 'fui'): 8,
#          ('fui', 'acompanhado'): 1,
#          ('acompanhado', 'ao'): 1,
#          ('ao', 'cemitério'): 4,
#          ('cemitério', 'por'): 1,
#          ('por', 'onze'): 1,
#          ('onze', 'amigos'): 1,
#          ('amigos', '.'): 2,
#          ('<s>', 'Onze'): 1,
#          ('Onze', 'amigos'): 1,
#          ('amigos', '!'): 2,
#          ('!', '</s>'): 295,
#          ('<s>', 'Verdade'): 5,
#          ('Verdade', 'é'): 5,
#          ('não', 'houve'): 4,
#          ('houve', 'cartas'): 1,
#          ('cartas', 'nem'): 1,
#          ('nem', 'anúncios'): 1,
#          ('anúncios', '.'): 1,
#          ('que', 'chovia'): 2,
#          ('chovia', '\x97'): 1,
#          ('\x97', 'peneirava'): 1,
#          ('peneirava', 'uma'): 1,
#          ('uma', 'chuvinha'): 1,
#          ('chuvinha', 'miúda'): 1,
#          ('miúda', ','): 2,
#          (',', 'triste'): 5,
#          ('triste', 'e'): 6,
#          ('e', 'constante'): 2,
#          ('constante', ','): 2,
#          (',', 'tão'): 19,
#          ('tão', 'constante'): 1,
#          ('constante', 'e'): 1,
#          ('e', 'tão'): 7,
#          ('tão', 'triste'): 5,
#          ('triste', ','): 11,
#          ('que', 'levou'): 1,
#          ('levou', 'um'): 1,
#          ('um', 'daqueles'): 1,
#          ('daqueles', 'fiéis'): 1,
#          ('fiéis', 'da'): 1,
#          ('da', 'última'): 3,
#          ('última', 'hora'): 2,
#          ('hora', 'a'): 1,
#          ('a', 'intercalar'): 2,
#          ('intercalar', 'esta'): 1,
#          ('esta', 'engenhosa'): 1,
#          ('engenhosa', 'idéia'): 1,
#          ('idéia', 'no'): 2,
#          ('no', 'discurso'): 1,
#          ('discurso', 'que'): 2,
#          ('que', 'proferiu'): 1,
#          ('proferiu', 'à'): 1,
#          ('à', 'beira'): 1,
#          ('beira', 'de'): 1,
#          ('de', 'minha'): 9,
#          ('minha', 'cova'): 1,
#          ('cova', ':'): 1,
#          (':', '\x97'): 32,
#          ('\x97', '\x93'): 10,
#          ('\x93', 'Vós'): 1,
#          ('Vós', ','): 2,
#          ('o', 'conhecestes'): 1,
#          ('conhecestes', ','): 1,
#          (',', 'meus'): 1,
#          ('meus', 'senhores'): 1,
#          ('senhores', ','): 1,
#          (',', 'vós'): 3,
#          ('vós', 'podeis'): 1,
#          ('podeis', 'dizer'): 1,
#          ('dizer', 'comigo'): 1,
#          ('comigo', 'que'): 3,
#          ('a', 'natureza'): 8,
#          ('natureza', 'parece'): 1,
#          ('parece', 'estar'): 2,
#          ('estar', 'chorando'): 1,
#          ('chorando', 'a'): 1,
#          ('a', 'perda'): 1,
#          ('perda', 'irreparável'): 1,
#          ('irreparável', 'de'): 1,
#          ('um', 'dos'): 21,
#          ('dos', 'mais'): 4,
#          ('mais', 'belos'): 2,
#          ('belos', 'caracteres'): 1,
#          ('caracteres', 'que'): 1,
#          ('que', 'têm'): 2,
#          ('têm', 'honrado'): 1,
#          ('honrado', 'a'): 1,
#          ('a', 'humanidade'): 1,
#          ('humanidade', '.'): 2,
#          ('<s>', 'Este'): 7,
#          ('Este', 'ar'): 2,
#          ('ar', 'sombrio'): 1,
#          ('sombrio', ','): 1,
#          (',', 'estas'): 2,
#          ('estas', 'gotas'): 1,
#          ('gotas', 'do'): 1,
#          ('do', 'céu'): 4,
#          ('céu', ','): 3,
#          (',', 'aquelas'): 1,
#          ('aquelas', 'nuvens'): 1,
#          ('nuvens', 'escuras'): 1,
#          ('escuras', 'que'): 1,
#          ('que', 'cobrem'): 1,
#          ('cobrem', 'o'): 1,
#          ('o', 'azul'): 1,
#          ('azul', 'como'): 1,
#          ('como', 'um'): 23,
#          ('um', 'crepe'): 1,
#          ('crepe', 'funéreo'): 1,
#          ('funéreo', ','): 1,
#          (',', 'tudo'): 9,
#          ('tudo', 'isso'): 12,
#          ('isso', 'é'): 3,
#          ('é', 'a'): 38,
#          ('a', 'dor'): 12,
#          ('dor', 'crua'): 1,
#          ('crua', 'e'): 1,
#          ('e', 'má'): 1,
#          ('má', 'que'): 1,
#          ('que', 'lhe'): 53,
#          ('lhe', 'rói'): 1,
#          ('rói', 'à'): 1,
#          ('à', 'Natureza'): 1,
#          ('Natureza', 'as'): 1,
#          ('as', 'mais'): 2,
#          ('mais', 'íntimas'): 2,
#          ('íntimas', 'entranhas'): 1,
#          ('entranhas', ';'): 1,
#          (';', 'tudo'): 3,
#          ('é', 'um'): 19,
#          ('um', 'sublime'): 1,
#          ('sublime', 'louvor'): 1,
#          ('louvor', 'ao'): 1,
#          ('ao', 'nosso'): 1,
#          ('nosso', 'ilustre'): 1,
#          ('ilustre', 'finado'): 1,
#          ('finado', '.\x94'): 1,
#          ('.\x94', '</s>'): 2,
#          ('<s>', 'Bom'): 2,
#          ('Bom', 'e'): 1,
#          ('e', 'fiel'): 1,
#          ('fiel', 'amigo'): 1,
#          ('amigo', '!'): 1,
#          ('Não', ','): 21,
#          ('não', 'me'): 37,
#          ('me', 'arrependo'): 2,
#          ('arrependo', 'das'): 1,
#          ('das', 'vinte'): 1,
#          ('vinte', 'apólices'): 1,
#          ('apólices', 'que'): 1,
#          ('lhe', 'deixei'): 1,
#          ('deixei', '.'): 1,
#          ('<s>', 'E'): 109,
#          ('E', 'foi'): 4,
#          ('foi', 'assim'): 4,
#          ('assim', 'que'): 8,
#          ('que', 'cheguei'): 4,
#          ('cheguei', 'à'): 1,
#          ('à', 'cláusula'): 1,
#          ('cláusula', 'dos'): 1,
#          ('dos', 'meus'): 15,
#          ('meus', 'dias'): 2,
#          ('dias', ';'): 4,
#          (';', 'foi'): 13,
#          ('me', 'encaminhei'): 1,
#          ('encaminhei', 'para'): 1,
#          ('para', 'o'): 38,
#          ('o', 'undiscovered'): 1,
#          ('undiscovered', 'country'): 1,
#          ('country', 'de'): 1,
#          ('de', 'Hamlet'): 2,
#          ('Hamlet', ','): 1,
#          (',', 'sem'): 77,
#          ('sem', 'as'): 2,
#          ('as', 'ânsias'): 1,
#          ('ânsias', 'nem'): 1,
#          ('nem', 'as'): 8,
#          ('as', 'dúvidas'): 1,
#          ('dúvidas', 'do'): 1,
#          ('do', 'moço'): 1,
#          ('moço', 'príncipe'): 1,
#          ('príncipe', ','): 1,
#          ('mas', 'pausado'): 1,
#          ('pausado', 'e'): 1,
#          ('e', 'trôpego'): 1,
#          ('trôpego', 'como'): 1,
#          ('como', 'quem'): 5,
#          ('quem', 'se'): 2,
#          ('se', 'retira'): 1,
#          ('retira', 'tarde'): 1,
#          ('tarde', 'do'): 1,
#          ('do', 'espetáculo'): 3,
#          ('espetáculo', '.'): 3,
#          ('<s>', 'Tarde'): 2,
#          ('Tarde', 'e'): 1,
#          ('e', 'aborrecido'): 2,
#          ('aborrecido', '.'): 3,
#          ('<s>', 'Viram'): 2,
#          ('Viram', '-'): 1,
#          ('me', 'ir'): 7,
#          ('ir', 'umas'): 1,
#          ('umas', 'nove'): 1,
#          ('nove', 'ou'): 1,
#          ('ou', 'dez'): 4,
#          ('dez', 'pessoas'): 2,
#          ('pessoas', ','): 2,
#          (',', 'entre'): 19,
#          ('entre', 'elas'): 1,
#          ('elas', 'três'): 1,
#          ('três', 'senhoras'): 2,
#          ('senhoras', ','): 3,
#          (',', 'minha'): 4,
#          ('minha', 'irmã'): 5,
#          ('irmã', 'Sabina'): 3,
#          ('Sabina', ','): 10,
#          ...})

# %% [markdown]
# Precisamos também contar os trigramas, assim, use o Counter nos trigramas na linha abaixo.

# %%
count_trigram = Counter(words_trigram)

# %% [markdown]
# Criaremos uma lista de bigramas e trigramas únicos para podermos gerar nosso modelo. Utilizaremos essa lista como chave do nosso dicionário de contagem.

# %%
bigram_key = list(count_bigram.keys())
trigram_key = list(count_trigram.keys())

# %% [markdown]
# Para o cálculo da frequência relativa de trigramas, precisamos, para cada trigrama, pegar o bigrama formado pelas primeiras duas palavras do trigrama. Assim, calculamos a probabilidade da última palavra do trigrama surgir no corpus, dado a aparição das duas primeiras palavras no trigrama:
#
# <center>$P(w_{3} | w_{1},w_{2}) = \frac{c(w_{1}, w_{2}, w_{3})}{c(w_{1}, w_{2})}$</center>
#
# Assim, para cada trigrama único, pegamos o bigrama correspondente e calculamos a probabilidade acima. Vamos colocar todos esses dados em um dataframe pandas, por isso, vamos criar listas com os bigramas correspondentes para cada trigrama (primeira e segunda palavra no trigrama) e a última palavra do trigrama, formando uma tabela.

# %%
list_bigram = []
list_lastword = []
list_probs = []

for t in trigram_key:
    key_bigram = (t[0], t[1])
    prob = count_trigram[t] / count_bigram[key_bigram]
    list_bigram.append(key_bigram)
    list_lastword.append(t[2])
    list_probs.append(prob)

# %% [markdown]
# A partir das listas criadas acima, vamos criar um dataframe pandas. Esse dataframe será nosso modelo linguístico.

# %%
model_df = pd.DataFrame({'bigram': list_bigram, 'lastword': list_lastword, 'prob': list_probs})
model_df
# Out:
#                        bigram    lastword      prob
# 0                  (<s>, <s>)     Romance  0.000262
# 1              (<s>, Romance)           ,  1.000000
# 2                (Romance, ,)    Memórias  1.000000
# 3               (,, Memórias)    Póstumas  1.000000
# 4        (Memórias, Póstumas)          de  0.800000
# 5              (Póstumas, de)        Brás  1.000000
# 6                  (de, Brás)       Cubas  0.833333
# 7               (Brás, Cubas)           ,  0.482759
# 8                  (Cubas, ,)        1880  0.062500
# 9                   (,, 1880)        </s>  1.000000
# 10               (1880, </s>)         <s>  1.000000
# 11                (</s>, <s>)         <s>  1.000000
# 12                 (<s>, <s>)    Memórias  0.000262
# 13            (<s>, Memórias)    Póstumas  1.000000
# 14              (Brás, Cubas)        </s>  0.034483
# 15              (Cubas, </s>)         <s>  1.000000
# 16                 (<s>, <s>)       Texto  0.000262
# 17               (<s>, Texto)           -  1.000000
# 18                 (Texto, -)       fonte  1.000000
# 19                 (-, fonte)           :  1.000000
# 20                 (fonte, :)        Obra  1.000000
# 21                  (:, Obra)    Completa  1.000000
# 22           (Obra, Completa)           ,  1.000000
# 23              (Completa, ,)     Machado  1.000000
# 24               (,, Machado)          de  1.000000
# 25              (Machado, de)       Assis  1.000000
# 26                (de, Assis)           ,  0.500000
# 27                 (Assis, ,)         Rio  1.000000
# 28                   (,, Rio)          de  1.000000
# 29                  (Rio, de)     Janeiro  1.000000
# ...                       ...         ...       ...
# 66437              (achei, -)          me  0.111111
# 66438               (com, um)     pequeno  0.020000
# 66439           (um, pequeno)       saldo  1.000000
# 66440        (pequeno, saldo)           ,  1.000000
# 66441              (saldo, ,)         que  1.000000
# 66442                  (é, a)  derradeira  0.026316
# 66443         (a, derradeira)    negativa  1.000000
# 66444  (derradeira, negativa)       deste  1.000000
# 66445       (negativa, deste)    capítulo  1.000000
# 66446       (deste, capítulo)          de  1.000000
# 66447          (capítulo, de)   negativas  0.500000
# 66448         (de, negativas)           :  0.500000
# 66449          (negativas, :)             1.000000
# 66450                  (:, )         Não  0.031250
# 66451                (, Não)        tive  0.016393
# 66452             (Não, tive)      filhos  0.500000
# 66453          (tive, filhos)           ,  1.000000
# 66454             (filhos, ,)         não  0.250000
# 66455                (,, não)   transmiti  0.005682
# 66456        (não, transmiti)           a  1.000000
# 66457          (transmiti, a)     nenhuma  1.000000
# 66458            (a, nenhuma)    criatura  1.000000
# 66459     (nenhuma, criatura)           o  1.000000
# 66460           (criatura, o)      legado  1.000000
# 66461             (o, legado)          da  1.000000
# 66462            (legado, da)       nossa  1.000000
# 66463             (da, nossa)     miséria  0.071429
# 66464        (nossa, miséria)           .  1.000000
# 66465              (<s>, <s>)         FIM  0.000262
# 66466              (<s>, FIM)        </s>  1.000000
#
# [66467 rows x 3 columns]

# %% [markdown]
# Vamos testar nosso dataframe. Crie um dataframe contendo apenas o bigrama ('Brás', 'Cubas').

# %%
bigram_df = model_df.loc[model_df['bigram'] == ('Brás', 'Cubas')]
bigram_df
# Out:
#               bigram lastword      prob
# 7      (Brás, Cubas)        ,  0.482759
# 14     (Brás, Cubas)     </s>  0.034483
# 92     (Brás, Cubas)      foi  0.034483
# 179    (Brás, Cubas)      são  0.034483
# 211    (Brás, Cubas)        (  0.034483
# 320    (Brás, Cubas)       se  0.034483
# 338    (Brás, Cubas)       um  0.034483
# 716    (Brás, Cubas)        .  0.206897
# 27329  (Brás, Cubas)        ;  0.068966
# 39094  (Brás, Cubas)      não  0.034483

# %% [markdown]
# Agora mostre que temos um modelo probabilístico. Para que um modelo seja probabilístico, precisamos que todas as probablidades de um dado bigrama somem 1. Complete a linha abaixo somando as probabilidades do dataframe criado acima. A soma deve ser aproximadamente 1.

# %%
sum(bigram_df['prob'])
# Out:
# 0.9999999999999998

# %% [markdown]
# Com o nosso modelo criado, vamos usá-lo para gerar texto. Para gerar texto temos que iniciar com o bigrama de início de sentença, pegar todos os trigramas que iniciam com esse bigrama e tomar a próxima palavra de acordo com sua probabilidade. O próximo bigrama será as duas últimas palavras do trigrama escolhido, isto é, pego a última palavra do bigrama atual e junto com a próxima palavra escolhida de acordo com a probabilidade. Complete o código abaixo para gerar o texto.

# %%
num_sents = 50
current_bigram = ('<s>', '<s>')
i = 0
while i < num_sents:
    df = model_df.loc[model_df['bigram'] == current_bigram]
    words = df['lastword'].values
    probs = df['prob'].values
    last_word = random.choices(words, probs)[0]
    
    current_bigram = (current_bigram[1], last_word)
    
    if last_word == '</s>':
        i+=1
    
    if last_word != '<s>' and last_word != '</s>':
        print(last_word, end=' ')
# Out:
# Fui ao enterro . CAPÍTULO CXXXVIII / A PROPÓSITO DE BOTAS Minha irmã encaminhou a candidatura de Lobo Neves , e estarás perdida ... morta ... e ele havia de mostrar de que o do Bocage ! Que há entre as unhas , que vence em eficácia o cálculo humano , e todos abençoarão esse canto de uma rígida e meiga companheira do homem ; meu cérebro , porque eu não era outra coisa além dos livros , e que antes , só a custo pela escada da direita , toda fechada , menos luzidios que os esperava um pouco turvados ; mas não sei se andaste bem ou mal ; esse entrou a rolar como a moeda , hem ? Capistrano de Abreu , noticiando a publicação de um modo malicioso ; talvez queiras uma coisa redonda e amarela . Creio que essa : orçam todas pela mesma vulgaridade ou fraqueza . Comíamos , é uma operação conveniente , como Ezequiel ; logo que chegou a me dar o sol , se não pode continuar assim , e , com quem dançara num célebre baile da Praia do Flamengo e de morte , é verdade ; se te não agradar , pago - me a boa fortuna de não escrever este , que viria outra vez de engordar tranqüilamente na cidade . Essa voz saía de mim , e a filha , dos teus dedos que praticaram o ato . Virgília tornou a falar . Viu - a ; mas sorriu , quando menos em juízo . Eu estava enjoado dessa abjeção tão cômica e tão profundos efeitos . Se ele a teu respeito , a arfar muito : Marcela ofereceu - me que não podia ser outra coisa no espírito dela estavam secos . Dutra veio dizer - lhes ler este capítulo escapou a Aristóteles . Na noite seguinte fui efetivamente à casa de D . Plácida era minha irmã , meu caro Brás Cubas , se os nossos olhos se fixam na ponta do botim ; declarei depois que estive a ponto de me dar o sol também , e não digo pela virtude em si , pareceu atentar na inconveniência daquela confissão ao amante de uma sugestão de meu pai tinha - a ao pé da moça , lépida como uma borboleta preta , que recuei um pouco triste . perguntou Marcela de pé , encostado a um prólogo explícito e longo . Longa foi a mesma coisa quando se não pode reger nem palpar . Deixe - me preciso enterrar magnificamente os meus instantes perdidos . exclamou . Olhávamos um para o chão , e com boa vontade da crítica !) O principal deles foi a primeira voz . Vamos juntos . Não me lembra o que isto é , se aterrada com a idéia do medo ... CAPÍTULO CIX / O BIBLIÔMANO Não pôde Eugênia encobrir a satisfação do triunfo . Então considerei que as parentas . A princípio não quis ; deixou ir pelas mãos fora nada menos do que eu tinha - lhe nas mãos , e abriu - o mal , era o anteparo da liberdade e conservação ; fazia um discurso ... redargüi ; não se lembra do capítulo CXXIX .  Sou o Borba , porém , esperar alguns anos . A violência não era excessiva a gratificação , se se não podem reaver integralmente ; mas sobretudo os acepipes do mestre eram deliciosos .  Que hei de dizer ? Conheces de sobejo tudo o que quiseres ... Olha a vara de marmelo ! Seguiram - se às vezes alguns reparos ao irmão ; com que eu vinha fazendo a mim mesmo ao voltar para casa . Nem eu . Saíra do Rio de Janeiro . Nunca me esqueceu esta circunstância , não recuarei das minhas , conchegou - me os olhos de Virgília , a destruição da dor é como a moeda , hem ? E concluía :  Já se vai sentindo que o meu cavalo de todos os correeiros te apuparam e desancaram . Vendo um embrulho misterioso . No dia seguinte , mandou - o , remira - se , rosnavam , com evidentes mostras de contentamento .  Sim ; o resto ? CAPÍTULO LVI / O PROGRAMA Em casa , dizendo que a transmissão da vida , sem enfeites , tendo longamente contrabandeado em escravos , habituara - se apressadamente da sala , que não aconteceu nada . AOS DEZENOVE ANOS DE IDADE Pois eu lembrei - me que os navios são dele ; entregue ao terror da morte ; eu dispus - me sorrir , quando torna aos outros homens . Ficando a sós , em presença de Virgília ; abanou a cabeça . Não , senhor , era uma aplicação política do banquete .  Muito esperto , concordava meu pai lhe ouvisse tal declaração ; creio to ...

# %% [markdown]
# Agora é a sua vez! Vamos criar um modelo mais performático para o corpus. Para isso, vamos usar 5-gramas. Usando a função ngrams, crie um modelo de 5-gramas e gere texto a partir dele.
#
# Lembre-se que precisamos do seguinte para criar o modelo:
#
# * Inserir tokens de inicio e fim de sentença adequados ao modelo, isto é, 4 tokens no início da sentença
# * Criar listas de 4-gramas e 5-gramas usando o ngrams
# * Contar os ngramas de cada lista
# * Calcular a probabilidade adequadamente
# * Criar o modelo em forma de dataframe
# * Usar o modelo para gerar texto
#
# Use o código acima como exemplo e crie o seu próprio modelo.

# %%
corpus = machado.sents('romance/marm05.txt')
corpus[:100]
# Out:
# [['Romance', ',', 'Memórias', 'Póstumas', 'de', 'Brás', 'Cubas', ',', '1880'], ['Memórias', 'Póstumas', 'de', 'Brás', 'Cubas'], ...]

# %%
words = []
for sent in corpus:
    sent.insert(0, '<s>')
    sent.insert(0, '<s>')
    sent.insert(0, '<s>')
    sent.insert(0, '<s>')
    sent.append('</s>')
    words.extend(sent)

# %%
n= 4
n2 = 5
forgram = ngrams(words, n)
fivegrams = ngrams(words, n2)

# %%
count_forgram = Counter(forgram)
count_forgram
# Out:
# Counter({('<s>', '<s>', '<s>', '<s>'): 3822,
#          ('<s>', '<s>', '<s>', 'Romance'): 1,
#          ('<s>', '<s>', 'Romance', ','): 1,
#          ('<s>', 'Romance', ',', 'Memórias'): 1,
#          ('Romance', ',', 'Memórias', 'Póstumas'): 1,
#          (',', 'Memórias', 'Póstumas', 'de'): 1,
#          ('Memórias', 'Póstumas', 'de', 'Brás'): 4,
#          ('Póstumas', 'de', 'Brás', 'Cubas'): 4,
#          ('de', 'Brás', 'Cubas', ','): 1,
#          ('Brás', 'Cubas', ',', '1880'): 1,
#          ('Cubas', ',', '1880', '</s>'): 1,
#          (',', '1880', '</s>', '<s>'): 1,
#          ('1880', '</s>', '<s>', '<s>'): 1,
#          ('</s>', '<s>', '<s>', '<s>'): 3821,
#          ('<s>', '<s>', '<s>', 'Memórias'): 1,
#          ('<s>', '<s>', 'Memórias', 'Póstumas'): 1,
#          ('<s>', 'Memórias', 'Póstumas', 'de'): 1,
#          ('de', 'Brás', 'Cubas', '</s>'): 1,
#          ('Brás', 'Cubas', '</s>', '<s>'): 1,
#          ('Cubas', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Texto'): 1,
#          ('<s>', '<s>', 'Texto', '-'): 1,
#          ('<s>', 'Texto', '-', 'fonte'): 1,
#          ('Texto', '-', 'fonte', ':'): 1,
#          ('-', 'fonte', ':', 'Obra'): 1,
#          ('fonte', ':', 'Obra', 'Completa'): 1,
#          (':', 'Obra', 'Completa', ','): 1,
#          ('Obra', 'Completa', ',', 'Machado'): 1,
#          ('Completa', ',', 'Machado', 'de'): 1,
#          (',', 'Machado', 'de', 'Assis'): 1,
#          ('Machado', 'de', 'Assis', ','): 1,
#          ('de', 'Assis', ',', 'Rio'): 1,
#          ('Assis', ',', 'Rio', 'de'): 1,
#          (',', 'Rio', 'de', 'Janeiro'): 1,
#          ('Rio', 'de', 'Janeiro', ':'): 1,
#          ('de', 'Janeiro', ':', 'Editora'): 1,
#          ('Janeiro', ':', 'Editora', 'Nova'): 1,
#          (':', 'Editora', 'Nova', 'Aguilar'): 1,
#          ('Editora', 'Nova', 'Aguilar', ','): 1,
#          ('Nova', 'Aguilar', ',', '1994'): 1,
#          ('Aguilar', ',', '1994', '.'): 1,
#          (',', '1994', '.', '</s>'): 1,
#          ('1994', '.', '</s>', '<s>'): 1,
#          ('.', '</s>', '<s>', '<s>'): 2813,
#          ('<s>', '<s>', '<s>', 'Publicado'): 1,
#          ('<s>', '<s>', 'Publicado', 'originalmente'): 1,
#          ('<s>', 'Publicado', 'originalmente', 'em'): 1,
#          ('Publicado', 'originalmente', 'em', 'folhetins'): 1,
#          ('originalmente', 'em', 'folhetins', ','): 1,
#          ('em', 'folhetins', ',', 'a'): 1,
#          ('folhetins', ',', 'a', 'partir'): 1,
#          (',', 'a', 'partir', 'de'): 1,
#          ('a', 'partir', 'de', 'março'): 1,
#          ('partir', 'de', 'março', 'de'): 1,
#          ('de', 'março', 'de', '1880'): 1,
#          ('março', 'de', '1880', ','): 1,
#          ('de', '1880', ',', 'na'): 1,
#          ('1880', ',', 'na', 'Revista'): 1,
#          (',', 'na', 'Revista', 'Brasileira'): 1,
#          ('na', 'Revista', 'Brasileira', '.'): 1,
#          ('Revista', 'Brasileira', '.', '</s>'): 1,
#          ('Brasileira', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Ao'): 33,
#          ('<s>', '<s>', 'Ao', 'verme'): 1,
#          ('<s>', 'Ao', 'verme', 'que'): 1,
#          ('Ao', 'verme', 'que', 'primeiro'): 1,
#          ('verme', 'que', 'primeiro', 'roeu'): 1,
#          ('que', 'primeiro', 'roeu', 'as'): 1,
#          ('primeiro', 'roeu', 'as', 'frias'): 1,
#          ('roeu', 'as', 'frias', 'carnes'): 1,
#          ('as', 'frias', 'carnes', 'do'): 1,
#          ('frias', 'carnes', 'do', 'meu'): 1,
#          ('carnes', 'do', 'meu', 'cadáver'): 1,
#          ('do', 'meu', 'cadáver', '</s>'): 1,
#          ('meu', 'cadáver', '</s>', '<s>'): 1,
#          ('cadáver', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'dedico'): 1,
#          ('<s>', '<s>', 'dedico', 'como'): 1,
#          ('<s>', 'dedico', 'como', 'saudosa'): 1,
#          ('dedico', 'como', 'saudosa', 'lembrança'): 1,
#          ('como', 'saudosa', 'lembrança', '</s>'): 1,
#          ('saudosa', 'lembrança', '</s>', '<s>'): 1,
#          ('lembrança', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'estas'): 1,
#          ('<s>', '<s>', 'estas', 'Memórias'): 1,
#          ('<s>', 'estas', 'Memórias', 'Póstumas'): 1,
#          ('estas', 'Memórias', 'Póstumas', '</s>'): 1,
#          ('Memórias', 'Póstumas', '</s>', '<s>'): 1,
#          ('Póstumas', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Prólogo'): 1,
#          ('<s>', '<s>', 'Prólogo', 'da'): 1,
#          ('<s>', 'Prólogo', 'da', 'terceira'): 1,
#          ('Prólogo', 'da', 'terceira', 'edição'): 1,
#          ('da', 'terceira', 'edição', '</s>'): 1,
#          ('terceira', 'edição', '</s>', '<s>'): 1,
#          ('edição', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'A'): 125,
#          ('<s>', '<s>', 'A', 'primeira'): 2,
#          ('<s>', 'A', 'primeira', 'edição'): 1,
#          ('A', 'primeira', 'edição', 'destas'): 1,
#          ('primeira', 'edição', 'destas', 'Memórias'): 1,
#          ('edição', 'destas', 'Memórias', 'Póstumas'): 1,
#          ('destas', 'Memórias', 'Póstumas', 'de'): 1,
#          ('de', 'Brás', 'Cubas', 'foi'): 1,
#          ('Brás', 'Cubas', 'foi', 'feita'): 1,
#          ('Cubas', 'foi', 'feita', 'aos'): 1,
#          ('foi', 'feita', 'aos', 'pedaços'): 1,
#          ('feita', 'aos', 'pedaços', 'na'): 1,
#          ('aos', 'pedaços', 'na', 'Revista'): 1,
#          ('pedaços', 'na', 'Revista', 'Brasileira'): 1,
#          ('na', 'Revista', 'Brasileira', ','): 1,
#          ('Revista', 'Brasileira', ',', 'pelos'): 1,
#          ('Brasileira', ',', 'pelos', 'anos'): 1,
#          (',', 'pelos', 'anos', 'de'): 1,
#          ('pelos', 'anos', 'de', '1880'): 1,
#          ('anos', 'de', '1880', '.'): 1,
#          ('de', '1880', '.', '</s>'): 1,
#          ('1880', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Postas'): 1,
#          ('<s>', '<s>', 'Postas', 'mais'): 1,
#          ('<s>', 'Postas', 'mais', 'tarde'): 1,
#          ('Postas', 'mais', 'tarde', 'em'): 1,
#          ('mais', 'tarde', 'em', 'livro'): 1,
#          ('tarde', 'em', 'livro', ','): 1,
#          ('em', 'livro', ',', 'corrigi'): 1,
#          ('livro', ',', 'corrigi', 'o'): 1,
#          (',', 'corrigi', 'o', 'texto'): 1,
#          ('corrigi', 'o', 'texto', 'em'): 1,
#          ('o', 'texto', 'em', 'vários'): 1,
#          ('texto', 'em', 'vários', 'lugares'): 1,
#          ('em', 'vários', 'lugares', '.'): 1,
#          ('vários', 'lugares', '.', '</s>'): 1,
#          ('lugares', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Agora'): 18,
#          ('<s>', '<s>', 'Agora', 'que'): 1,
#          ('<s>', 'Agora', 'que', 'tive'): 1,
#          ('Agora', 'que', 'tive', 'de'): 1,
#          ('que', 'tive', 'de', 'o'): 1,
#          ('tive', 'de', 'o', 'rever'): 1,
#          ('de', 'o', 'rever', 'para'): 1,
#          ('o', 'rever', 'para', 'a'): 1,
#          ('rever', 'para', 'a', 'terceira'): 1,
#          ('para', 'a', 'terceira', 'edição'): 1,
#          ('a', 'terceira', 'edição', ','): 1,
#          ('terceira', 'edição', ',', 'emendei'): 1,
#          ('edição', ',', 'emendei', 'ainda'): 1,
#          (',', 'emendei', 'ainda', 'alguma'): 1,
#          ('emendei', 'ainda', 'alguma', 'coisa'): 1,
#          ('ainda', 'alguma', 'coisa', 'e'): 1,
#          ('alguma', 'coisa', 'e', 'suprimi'): 1,
#          ('coisa', 'e', 'suprimi', 'duas'): 1,
#          ('e', 'suprimi', 'duas', 'ou'): 1,
#          ('suprimi', 'duas', 'ou', 'três'): 1,
#          ('duas', 'ou', 'três', 'dúzias'): 1,
#          ('ou', 'três', 'dúzias', 'de'): 1,
#          ('três', 'dúzias', 'de', 'linhas'): 1,
#          ('dúzias', 'de', 'linhas', '.'): 1,
#          ('de', 'linhas', '.', '</s>'): 1,
#          ('linhas', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Assim'): 12,
#          ('<s>', '<s>', 'Assim', 'composta'): 1,
#          ('<s>', 'Assim', 'composta', ','): 1,
#          ('Assim', 'composta', ',', 'sai'): 1,
#          ('composta', ',', 'sai', 'novamente'): 1,
#          (',', 'sai', 'novamente', 'à'): 1,
#          ('sai', 'novamente', 'à', 'luz'): 1,
#          ('novamente', 'à', 'luz', 'esta'): 1,
#          ('à', 'luz', 'esta', 'obra'): 1,
#          ('luz', 'esta', 'obra', 'que'): 1,
#          ('esta', 'obra', 'que', 'alguma'): 1,
#          ('obra', 'que', 'alguma', 'benevolência'): 1,
#          ('que', 'alguma', 'benevolência', 'parece'): 1,
#          ('alguma', 'benevolência', 'parece', 'ter'): 1,
#          ('benevolência', 'parece', 'ter', 'encontrado'): 1,
#          ('parece', 'ter', 'encontrado', 'no'): 1,
#          ('ter', 'encontrado', 'no', 'público'): 1,
#          ('encontrado', 'no', 'público', '.'): 1,
#          ('no', 'público', '.', '</s>'): 1,
#          ('público', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Capistrano'): 1,
#          ('<s>', '<s>', 'Capistrano', 'de'): 1,
#          ('<s>', 'Capistrano', 'de', 'Abreu'): 1,
#          ('Capistrano', 'de', 'Abreu', ','): 1,
#          ('de', 'Abreu', ',', 'noticiando'): 1,
#          ('Abreu', ',', 'noticiando', 'a'): 1,
#          (',', 'noticiando', 'a', 'publicação'): 1,
#          ('noticiando', 'a', 'publicação', 'do'): 1,
#          ('a', 'publicação', 'do', 'livro'): 1,
#          ('publicação', 'do', 'livro', ','): 1,
#          ('do', 'livro', ',', 'perguntava'): 1,
#          ('livro', ',', 'perguntava', ':'): 1,
#          (',', 'perguntava', ':', '\x93'): 1,
#          ('perguntava', ':', '\x93', 'As'): 1,
#          (':', '\x93', 'As', 'Memórias'): 1,
#          ('\x93', 'As', 'Memórias', 'Póstumas'): 1,
#          ('As', 'Memórias', 'Póstumas', 'de'): 1,
#          ('de', 'Brás', 'Cubas', 'são'): 1,
#          ('Brás', 'Cubas', 'são', 'um'): 1,
#          ('Cubas', 'são', 'um', 'romance'): 1,
#          ('são', 'um', 'romance', '?\x94'): 1,
#          ('um', 'romance', '?\x94', 'Macedo'): 1,
#          ('romance', '?\x94', 'Macedo', 'Soares'): 1,
#          ('?\x94', 'Macedo', 'Soares', ','): 1,
#          ('Macedo', 'Soares', ',', 'em'): 1,
#          ('Soares', ',', 'em', 'carta'): 1,
#          (',', 'em', 'carta', 'que'): 1,
#          ('em', 'carta', 'que', 'me'): 1,
#          ('carta', 'que', 'me', 'escreveu'): 1,
#          ('que', 'me', 'escreveu', 'por'): 1,
#          ('me', 'escreveu', 'por', 'esse'): 1,
#          ('escreveu', 'por', 'esse', 'tempo'): 1,
#          ('por', 'esse', 'tempo', ','): 1,
#          ('esse', 'tempo', ',', 'recordava'): 1,
#          ('tempo', ',', 'recordava', 'amigamente'): 1,
#          (',', 'recordava', 'amigamente', 'as'): 1,
#          ('recordava', 'amigamente', 'as', 'Viagens'): 1,
#          ('amigamente', 'as', 'Viagens', 'na'): 1,
#          ('as', 'Viagens', 'na', 'minha'): 1,
#          ('Viagens', 'na', 'minha', 'terra'): 1,
#          ('na', 'minha', 'terra', '.'): 1,
#          ('minha', 'terra', '.', '</s>'): 1,
#          ('terra', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', 'Ao', 'primeiro'): 1,
#          ('<s>', 'Ao', 'primeiro', 'respondia'): 1,
#          ('Ao', 'primeiro', 'respondia', 'já'): 1,
#          ('primeiro', 'respondia', 'já', 'o'): 1,
#          ('respondia', 'já', 'o', 'defunto'): 1,
#          ('já', 'o', 'defunto', 'Brás'): 1,
#          ('o', 'defunto', 'Brás', 'Cubas'): 1,
#          ('defunto', 'Brás', 'Cubas', '('): 1,
#          ('Brás', 'Cubas', '(', 'como'): 1,
#          ('Cubas', '(', 'como', 'o'): 1,
#          ('(', 'como', 'o', 'leitor'): 1,
#          ('como', 'o', 'leitor', 'viu'): 1,
#          ('o', 'leitor', 'viu', 'e'): 1,
#          ('leitor', 'viu', 'e', 'verá'): 1,
#          ('viu', 'e', 'verá', 'no'): 1,
#          ('e', 'verá', 'no', 'prólogo'): 1,
#          ('verá', 'no', 'prólogo', 'dele'): 1,
#          ('no', 'prólogo', 'dele', 'que'): 1,
#          ('prólogo', 'dele', 'que', 'vai'): 1,
#          ('dele', 'que', 'vai', 'adiante'): 1,
#          ('que', 'vai', 'adiante', ')'): 1,
#          ('vai', 'adiante', ')', 'que'): 1,
#          ('adiante', ')', 'que', 'sim'): 1,
#          (')', 'que', 'sim', 'e'): 1,
#          ('que', 'sim', 'e', 'que'): 1,
#          ('sim', 'e', 'que', 'não'): 1,
#          ('e', 'que', 'não', ','): 1,
#          ('que', 'não', ',', 'que'): 2,
#          ('não', ',', 'que', 'era'): 1,
#          (',', 'que', 'era', 'romance'): 1,
#          ('que', 'era', 'romance', 'para'): 1,
#          ('era', 'romance', 'para', 'uns'): 1,
#          ('romance', 'para', 'uns', 'e'): 1,
#          ('para', 'uns', 'e', 'não'): 1,
#          ('uns', 'e', 'não', 'o'): 1,
#          ('e', 'não', 'o', 'era'): 1,
#          ('não', 'o', 'era', 'para'): 1,
#          ('o', 'era', 'para', 'outros'): 1,
#          ('era', 'para', 'outros', '.'): 1,
#          ('para', 'outros', '.', '</s>'): 1,
#          ('outros', '.', '</s>', '<s>'): 10,
#          ('<s>', '<s>', '<s>', 'Quanto'): 16,
#          ('<s>', '<s>', 'Quanto', 'ao'): 4,
#          ('<s>', 'Quanto', 'ao', 'segundo'): 1,
#          ('Quanto', 'ao', 'segundo', ','): 1,
#          ('ao', 'segundo', ',', 'assim'): 1,
#          ('segundo', ',', 'assim', 'se'): 1,
#          (',', 'assim', 'se', 'explicou'): 1,
#          ('assim', 'se', 'explicou', 'o'): 1,
#          ('se', 'explicou', 'o', 'finado'): 1,
#          ('explicou', 'o', 'finado', ':'): 1,
#          ('o', 'finado', ':', '\x93'): 1,
#          ('finado', ':', '\x93', 'Trata'): 1,
#          (':', '\x93', 'Trata', '-'): 1,
#          ('\x93', 'Trata', '-', 'se'): 1,
#          ('Trata', '-', 'se', 'de'): 1,
#          ('-', 'se', 'de', 'uma'): 1,
#          ('se', 'de', 'uma', 'obra'): 1,
#          ('de', 'uma', 'obra', 'difusa'): 2,
#          ('uma', 'obra', 'difusa', ','): 2,
#          ('obra', 'difusa', ',', 'na'): 2,
#          ('difusa', ',', 'na', 'qual'): 2,
#          (',', 'na', 'qual', 'eu'): 2,
#          ('na', 'qual', 'eu', ','): 2,
#          ('qual', 'eu', ',', 'Brás'): 2,
#          ('eu', ',', 'Brás', 'Cubas'): 3,
#          (',', 'Brás', 'Cubas', ','): 4,
#          ('Brás', 'Cubas', ',', 'se'): 2,
#          ('Cubas', ',', 'se', 'adotei'): 2,
#          (',', 'se', 'adotei', 'a'): 2,
#          ('se', 'adotei', 'a', 'forma'): 2,
#          ('adotei', 'a', 'forma', 'livre'): 2,
#          ('a', 'forma', 'livre', 'de'): 2,
#          ('forma', 'livre', 'de', 'um'): 2,
#          ('livre', 'de', 'um', 'Sterne'): 2,
#          ('de', 'um', 'Sterne', 'ou'): 1,
#          ('um', 'Sterne', 'ou', 'de'): 1,
#          ('Sterne', 'ou', 'de', 'um'): 1,
#          ('ou', 'de', 'um', 'Xavier'): 2,
#          ('de', 'um', 'Xavier', 'de'): 2,
#          ('um', 'Xavier', 'de', 'Maistre'): 2,
#          ('Xavier', 'de', 'Maistre', ','): 2,
#          ('de', 'Maistre', ',', 'não'): 2,
#          ('Maistre', ',', 'não', 'sei'): 2,
#          (',', 'não', 'sei', 'se'): 8,
#          ('não', 'sei', 'se', 'lhe'): 2,
#          ('sei', 'se', 'lhe', 'meti'): 2,
#          ('se', 'lhe', 'meti', 'algumas'): 2,
#          ('lhe', 'meti', 'algumas', 'rabugens'): 2,
#          ('meti', 'algumas', 'rabugens', 'de'): 2,
#          ('algumas', 'rabugens', 'de', 'pessimismo'): 2,
#          ('rabugens', 'de', 'pessimismo', '.\x94'): 1,
#          ('de', 'pessimismo', '.\x94', 'Toda'): 1,
#          ('pessimismo', '.\x94', 'Toda', 'essa'): 1,
#          ('.\x94', 'Toda', 'essa', 'gente'): 1,
#          ('Toda', 'essa', 'gente', 'viajou'): 1,
#          ('essa', 'gente', 'viajou', ':'): 1,
#          ('gente', 'viajou', ':', 'Xavier'): 1,
#          ('viajou', ':', 'Xavier', 'de'): 1,
#          (':', 'Xavier', 'de', 'Maistre'): 1,
#          ('Xavier', 'de', 'Maistre', 'à'): 1,
#          ('de', 'Maistre', 'à', 'roda'): 1,
#          ('Maistre', 'à', 'roda', 'do'): 1,
#          ('à', 'roda', 'do', 'quarto'): 1,
#          ('roda', 'do', 'quarto', ','): 1,
#          ('do', 'quarto', ',', 'Garret'): 1,
#          ('quarto', ',', 'Garret', 'na'): 1,
#          (',', 'Garret', 'na', 'terra'): 1,
#          ('Garret', 'na', 'terra', 'dele'): 1,
#          ('na', 'terra', 'dele', ','): 1,
#          ('terra', 'dele', ',', 'Sterne'): 1,
#          ('dele', ',', 'Sterne', 'na'): 1,
#          (',', 'Sterne', 'na', 'terra'): 1,
#          ('Sterne', 'na', 'terra', 'dos'): 1,
#          ('na', 'terra', 'dos', 'outros'): 1,
#          ('terra', 'dos', 'outros', '.'): 1,
#          ('dos', 'outros', '.', '</s>'): 4,
#          ('<s>', '<s>', '<s>', 'De'): 31,
#          ('<s>', '<s>', 'De', 'Brás'): 1,
#          ('<s>', 'De', 'Brás', 'Cubas'): 1,
#          ('De', 'Brás', 'Cubas', 'se'): 1,
#          ('Brás', 'Cubas', 'se', 'pode'): 1,
#          ('Cubas', 'se', 'pode', 'dizer'): 1,
#          ('se', 'pode', 'dizer', 'que'): 1,
#          ('pode', 'dizer', 'que', 'viajou'): 1,
#          ('dizer', 'que', 'viajou', 'à'): 1,
#          ('que', 'viajou', 'à', 'roda'): 1,
#          ('viajou', 'à', 'roda', 'da'): 1,
#          ('à', 'roda', 'da', 'vida'): 1,
#          ('roda', 'da', 'vida', '.'): 1,
#          ('da', 'vida', '.', '</s>'): 4,
#          ('vida', '.', '</s>', '<s>'): 12,
#          ('<s>', '<s>', '<s>', 'O'): 110,
#          ('<s>', '<s>', 'O', 'que'): 14,
#          ('<s>', 'O', 'que', 'faz'): 1,
#          ('O', 'que', 'faz', 'do'): 1,
#          ('que', 'faz', 'do', 'meu'): 1,
#          ('faz', 'do', 'meu', 'Brás'): 1,
#          ('do', 'meu', 'Brás', 'Cubas'): 1,
#          ('meu', 'Brás', 'Cubas', 'um'): 1,
#          ('Brás', 'Cubas', 'um', 'autor'): 1,
#          ('Cubas', 'um', 'autor', 'particular'): 1,
#          ('um', 'autor', 'particular', 'é'): 1,
#          ('autor', 'particular', 'é', 'o'): 1,
#          ('particular', 'é', 'o', 'que'): 1,
#          ('é', 'o', 'que', 'ele'): 2,
#          ('o', 'que', 'ele', 'chama'): 1,
#          ('que', 'ele', 'chama', '\x93'): 1,
#          ('ele', 'chama', '\x93', 'rabugens'): 1,
#          ('chama', '\x93', 'rabugens', 'de'): 1,
#          ('\x93', 'rabugens', 'de', 'pessimismo'): 1,
#          ('rabugens', 'de', 'pessimismo', '\x94.'): 1,
#          ('de', 'pessimismo', '\x94.', '</s>'): 1,
#          ('pessimismo', '\x94.', '</s>', '<s>'): 1,
#          ('\x94.', '</s>', '<s>', '<s>'): 12,
#          ('<s>', '<s>', '<s>', 'Há'): 9,
#          ('<s>', '<s>', 'Há', 'na'): 1,
#          ('<s>', 'Há', 'na', 'alma'): 1,
#          ('Há', 'na', 'alma', 'deste'): 1,
#          ('na', 'alma', 'deste', 'livro'): 1,
#          ('alma', 'deste', 'livro', ','): 1,
#          ('deste', 'livro', ',', 'por'): 1,
#          ('livro', ',', 'por', 'mais'): 1,
#          (',', 'por', 'mais', 'risonho'): 1,
#          ('por', 'mais', 'risonho', 'que'): 1,
#          ('mais', 'risonho', 'que', 'pareça'): 1,
#          ('risonho', 'que', 'pareça', ','): 1,
#          ('que', 'pareça', ',', 'um'): 1,
#          ('pareça', ',', 'um', 'sentimento'): 1,
#          (',', 'um', 'sentimento', 'amargo'): 1,
#          ('um', 'sentimento', 'amargo', 'e'): 1,
#          ('sentimento', 'amargo', 'e', 'áspero'): 1,
#          ('amargo', 'e', 'áspero', ','): 1,
#          ('e', 'áspero', ',', 'que'): 1,
#          ('áspero', ',', 'que', 'está'): 1,
#          (',', 'que', 'está', 'longe'): 1,
#          ('que', 'está', 'longe', 'de'): 1,
#          ('está', 'longe', 'de', 'vir'): 1,
#          ('longe', 'de', 'vir', 'de'): 1,
#          ('de', 'vir', 'de', 'seus'): 1,
#          ('vir', 'de', 'seus', 'modelos'): 1,
#          ('de', 'seus', 'modelos', '.'): 1,
#          ('seus', 'modelos', '.', '</s>'): 1,
#          ('modelos', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'É'): 17,
#          ('<s>', '<s>', 'É', 'taça'): 1,
#          ('<s>', 'É', 'taça', 'que'): 1,
#          ('É', 'taça', 'que', 'pode'): 1,
#          ('taça', 'que', 'pode', 'ter'): 1,
#          ('que', 'pode', 'ter', 'lavores'): 1,
#          ('pode', 'ter', 'lavores', 'de'): 1,
#          ('ter', 'lavores', 'de', 'igual'): 1,
#          ('lavores', 'de', 'igual', 'escola'): 1,
#          ('de', 'igual', 'escola', ','): 1,
#          ('igual', 'escola', ',', 'mas'): 1,
#          ('escola', ',', 'mas', 'leva'): 1,
#          (',', 'mas', 'leva', 'outro'): 1,
#          ('mas', 'leva', 'outro', 'vinho'): 1,
#          ('leva', 'outro', 'vinho', '.'): 1,
#          ('outro', 'vinho', '.', '</s>'): 1,
#          ('vinho', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Não'): 185,
#          ('<s>', '<s>', 'Não', 'digo'): 10,
#          ('<s>', 'Não', 'digo', 'mais'): 2,
#          ('Não', 'digo', 'mais', 'para'): 1,
#          ('digo', 'mais', 'para', 'não'): 1,
#          ('mais', 'para', 'não', 'entrar'): 1,
#          ('para', 'não', 'entrar', 'na'): 1,
#          ('não', 'entrar', 'na', 'crítica'): 1,
#          ('entrar', 'na', 'crítica', 'de'): 1,
#          ('na', 'crítica', 'de', 'um'): 1,
#          ('crítica', 'de', 'um', 'defunto'): 1,
#          ('de', 'um', 'defunto', ','): 1,
#          ('um', 'defunto', ',', 'que'): 1,
#          ('defunto', ',', 'que', 'se'): 1,
#          (',', 'que', 'se', 'pintou'): 1,
#          ('que', 'se', 'pintou', 'a'): 1,
#          ('se', 'pintou', 'a', 'si'): 1,
#          ('pintou', 'a', 'si', 'e'): 1,
#          ('a', 'si', 'e', 'a'): 1,
#          ('si', 'e', 'a', 'outros'): 1,
#          ('e', 'a', 'outros', ','): 1,
#          ('a', 'outros', ',', 'conforme'): 1,
#          ('outros', ',', 'conforme', 'lhe'): 1,
#          (',', 'conforme', 'lhe', 'pareceu'): 1,
#          ('conforme', 'lhe', 'pareceu', 'melhor'): 1,
#          ('lhe', 'pareceu', 'melhor', 'e'): 1,
#          ('pareceu', 'melhor', 'e', 'mais'): 1,
#          ('melhor', 'e', 'mais', 'certo'): 1,
#          ('e', 'mais', 'certo', '.'): 1,
#          ('mais', 'certo', '.', '</s>'): 1,
#          ('certo', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Machado'): 1,
#          ('<s>', '<s>', 'Machado', 'de'): 1,
#          ('<s>', 'Machado', 'de', 'Assis'): 1,
#          ('Machado', 'de', 'Assis', '.'): 1,
#          ('de', 'Assis', '.', '</s>'): 1,
#          ('Assis', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'AO'): 1,
#          ('<s>', '<s>', 'AO', 'LEITOR'): 1,
#          ('<s>', 'AO', 'LEITOR', '</s>'): 1,
#          ('AO', 'LEITOR', '</s>', '<s>'): 1,
#          ('LEITOR', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Que'): 39,
#          ('<s>', '<s>', 'Que', 'Stendhal'): 1,
#          ('<s>', 'Que', 'Stendhal', 'confessasse'): 1,
#          ('Que', 'Stendhal', 'confessasse', 'haver'): 1,
#          ('Stendhal', 'confessasse', 'haver', 'escrito'): 1,
#          ('confessasse', 'haver', 'escrito', 'um'): 1,
#          ('haver', 'escrito', 'um', 'de'): 1,
#          ('escrito', 'um', 'de', 'seus'): 1,
#          ('um', 'de', 'seus', 'livros'): 1,
#          ('de', 'seus', 'livros', 'para'): 1,
#          ('seus', 'livros', 'para', 'cem'): 1,
#          ('livros', 'para', 'cem', 'leitores'): 1,
#          ('para', 'cem', 'leitores', ','): 1,
#          ('cem', 'leitores', ',', 'coisa'): 1,
#          ('leitores', ',', 'coisa', 'é'): 1,
#          (',', 'coisa', 'é', 'que'): 1,
#          ('coisa', 'é', 'que', 'admira'): 1,
#          ('é', 'que', 'admira', 'e'): 1,
#          ('que', 'admira', 'e', 'consterna'): 1,
#          ('admira', 'e', 'consterna', '.'): 1,
#          ('e', 'consterna', '.', '</s>'): 1,
#          ('consterna', '.', '</s>', '<s>'): 1,
#          ('<s>', 'O', 'que', 'não'): 2,
#          ('O', 'que', 'não', 'admira'): 1,
#          ('que', 'não', 'admira', ','): 1,
#          ('não', 'admira', ',', 'nem'): 1,
#          ('admira', ',', 'nem', 'provavelmente'): 1,
#          (',', 'nem', 'provavelmente', 'consternará'): 1,
#          ('nem', 'provavelmente', 'consternará', 'é'): 1,
#          ('provavelmente', 'consternará', 'é', 'se'): 1,
#          ('consternará', 'é', 'se', 'este'): 1,
#          ('é', 'se', 'este', 'outro'): 1,
#          ('se', 'este', 'outro', 'livro'): 1,
#          ('este', 'outro', 'livro', 'não'): 1,
#          ('outro', 'livro', 'não', 'tiver'): 1,
#          ('livro', 'não', 'tiver', 'os'): 1,
#          ('não', 'tiver', 'os', 'cem'): 1,
#          ('tiver', 'os', 'cem', 'leitores'): 1,
#          ('os', 'cem', 'leitores', 'de'): 1,
#          ('cem', 'leitores', 'de', 'Stendhal'): 1,
#          ('leitores', 'de', 'Stendhal', ','): 1,
#          ('de', 'Stendhal', ',', 'nem'): 1,
#          ('Stendhal', ',', 'nem', 'cinqüenta'): 1,
#          (',', 'nem', 'cinqüenta', ','): 1,
#          ('nem', 'cinqüenta', ',', 'nem'): 1,
#          ('cinqüenta', ',', 'nem', 'vinte'): 1,
#          (',', 'nem', 'vinte', 'e'): 1,
#          ('nem', 'vinte', 'e', ','): 1,
#          ('vinte', 'e', ',', 'quando'): 1,
#          ('e', ',', 'quando', 'muito'): 1,
#          (',', 'quando', 'muito', ','): 2,
#          ('quando', 'muito', ',', 'dez'): 1,
#          ('muito', ',', 'dez', '.'): 1,
#          (',', 'dez', '.', '</s>'): 1,
#          ('dez', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Dez'): 1,
#          ('<s>', '<s>', 'Dez', '?'): 1,
#          ('<s>', 'Dez', '?', '</s>'): 1,
#          ('Dez', '?', '</s>', '<s>'): 1,
#          ('?', '</s>', '<s>', '<s>'): 262,
#          ('<s>', '<s>', '<s>', 'Talvez'): 30,
#          ('<s>', '<s>', 'Talvez', 'cinco'): 2,
#          ('<s>', 'Talvez', 'cinco', '.'): 1,
#          ('Talvez', 'cinco', '.', '</s>'): 1,
#          ('cinco', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Trata'): 3,
#          ('<s>', '<s>', 'Trata', '-'): 2,
#          ('<s>', 'Trata', '-', 'se'): 1,
#          ('Trata', '-', 'se', ','): 1,
#          ('-', 'se', ',', 'na'): 1,
#          ('se', ',', 'na', 'verdade'): 1,
#          (',', 'na', 'verdade', ','): 4,
#          ('na', 'verdade', ',', 'de'): 1,
#          ('verdade', ',', 'de', 'uma'): 1,
#          (',', 'de', 'uma', 'obra'): 1,
#          ('de', 'um', 'Sterne', ','): 1,
#          ('um', 'Sterne', ',', 'ou'): 1,
#          ('Sterne', ',', 'ou', 'de'): 1,
#          (',', 'ou', 'de', 'um'): 1,
#          ('rabugens', 'de', 'pessimismo', '.'): 1,
#          ('de', 'pessimismo', '.', '</s>'): 1,
#          ('pessimismo', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Pode'): 1,
#          ('<s>', '<s>', 'Pode', 'ser'): 1,
#          ('<s>', 'Pode', 'ser', '.'): 1,
#          ('Pode', 'ser', '.', '</s>'): 2,
#          ('ser', '.', '</s>', '<s>'): 4,
#          ('<s>', '<s>', '<s>', 'Obra'): 1,
#          ('<s>', '<s>', 'Obra', 'de'): 1,
#          ('<s>', 'Obra', 'de', 'finado'): 1,
#          ('Obra', 'de', 'finado', '.'): 1,
#          ('de', 'finado', '.', '</s>'): 1,
#          ('finado', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Escrevi'): 2,
#          ('<s>', '<s>', 'Escrevi', '-'): 1,
#          ('<s>', 'Escrevi', '-', 'a'): 1,
#          ('Escrevi', '-', 'a', 'com'): 1,
#          ('-', 'a', 'com', 'a'): 2,
#          ('a', 'com', 'a', 'pena'): 1,
#          ('com', 'a', 'pena', 'da'): 1,
#          ('a', 'pena', 'da', 'galhofa'): 1,
#          ('pena', 'da', 'galhofa', 'e'): 1,
#          ('da', 'galhofa', 'e', 'a'): 1,
#          ('galhofa', 'e', 'a', 'tinta'): 1,
#          ('e', 'a', 'tinta', 'da'): 1,
#          ('a', 'tinta', 'da', 'melancolia'): 1,
#          ('tinta', 'da', 'melancolia', ','): 1,
#          ('da', 'melancolia', ',', 'e'): 1,
#          ('melancolia', ',', 'e', 'não'): 1,
#          (',', 'e', 'não', 'é'): 5,
#          ('e', 'não', 'é', 'difícil'): 1,
#          ('não', 'é', 'difícil', 'antever'): 1,
#          ('é', 'difícil', 'antever', 'o'): 1,
#          ('difícil', 'antever', 'o', 'que'): 1,
#          ('antever', 'o', 'que', 'poderá'): 1,
#          ('o', 'que', 'poderá', 'sair'): 1,
#          ('que', 'poderá', 'sair', 'desse'): 1,
#          ('poderá', 'sair', 'desse', 'conúbio'): 1,
#          ('sair', 'desse', 'conúbio', '.'): 1,
#          ('desse', 'conúbio', '.', '</s>'): 1,
#          ('conúbio', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Acresce'): 3,
#          ('<s>', '<s>', 'Acresce', 'que'): 3,
#          ('<s>', 'Acresce', 'que', 'a'): 1,
#          ('Acresce', 'que', 'a', 'gente'): 1,
#          ('que', 'a', 'gente', 'grave'): 1,
#          ('a', 'gente', 'grave', 'achará'): 1,
#          ('gente', 'grave', 'achará', 'no'): 1,
#          ('grave', 'achará', 'no', 'livro'): 1,
#          ('achará', 'no', 'livro', 'umas'): 1,
#          ('no', 'livro', 'umas', 'aparências'): 1,
#          ('livro', 'umas', 'aparências', 'de'): 1,
#          ('umas', 'aparências', 'de', 'puro'): 1,
#          ('aparências', 'de', 'puro', 'romance'): 1,
#          ('de', 'puro', 'romance', ','): 1,
#          ('puro', 'romance', ',', 'ao'): 1,
#          ('romance', ',', 'ao', 'passo'): 1,
#          (',', 'ao', 'passo', 'que'): 8,
#          ('ao', 'passo', 'que', 'a'): 3,
#          ('passo', 'que', 'a', 'gente'): 1,
#          ('que', 'a', 'gente', 'frívola'): 1,
#          ('a', 'gente', 'frívola', 'não'): 1,
#          ('gente', 'frívola', 'não', 'achará'): 1,
#          ('frívola', 'não', 'achará', 'nele'): 1,
#          ('não', 'achará', 'nele', 'o'): 1,
#          ('achará', 'nele', 'o', 'seu'): 1,
#          ('nele', 'o', 'seu', 'romance'): 1,
#          ('o', 'seu', 'romance', 'usual'): 1,
#          ('seu', 'romance', 'usual', ';'): 1,
#          ('romance', 'usual', ';', 'ei'): 1,
#          ('usual', ';', 'ei', '-'): 1,
#          (';', 'ei', '-', 'lo'): 2,
#          ('ei', '-', 'lo', 'aí'): 1,
#          ('-', 'lo', 'aí', 'fica'): 1,
#          ('lo', 'aí', 'fica', 'privado'): 1,
#          ('aí', 'fica', 'privado', 'da'): 1,
#          ('fica', 'privado', 'da', 'estima'): 1,
#          ('privado', 'da', 'estima', 'dos'): 1,
#          ('da', 'estima', 'dos', 'graves'): 1,
#          ('estima', 'dos', 'graves', 'e'): 1,
#          ('dos', 'graves', 'e', 'do'): 1,
#          ('graves', 'e', 'do', 'amor'): 1,
#          ('e', 'do', 'amor', 'dos'): 1,
#          ('do', 'amor', 'dos', 'frívolos'): 1,
#          ('amor', 'dos', 'frívolos', ','): 1,
#          ('dos', 'frívolos', ',', 'que'): 1,
#          ('frívolos', ',', 'que', 'são'): 1,
#          (',', 'que', 'são', 'as'): 1,
#          ('que', 'são', 'as', 'duas'): 1,
#          ('são', 'as', 'duas', 'colunas'): 1,
#          ('as', 'duas', 'colunas', 'máximas'): 1,
#          ('duas', 'colunas', 'máximas', 'da'): 1,
#          ('colunas', 'máximas', 'da', 'opinião'): 1,
#          ('máximas', 'da', 'opinião', '.'): 1,
#          ('da', 'opinião', '.', '</s>'): 2,
#          ('opinião', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Mas'): 68,
#          ('<s>', '<s>', 'Mas', 'eu'): 10,
#          ('<s>', 'Mas', 'eu', 'ainda'): 1,
#          ('Mas', 'eu', 'ainda', 'espero'): 1,
#          ('eu', 'ainda', 'espero', 'angariar'): 1,
#          ('ainda', 'espero', 'angariar', 'as'): 1,
#          ('espero', 'angariar', 'as', 'simpatias'): 1,
#          ('angariar', 'as', 'simpatias', 'da'): 1,
#          ('as', 'simpatias', 'da', 'opinião'): 1,
#          ('simpatias', 'da', 'opinião', ','): 1,
#          ('da', 'opinião', ',', 'e'): 1,
#          ('opinião', ',', 'e', 'o'): 1,
#          (',', 'e', 'o', 'primeiro'): 1,
#          ('e', 'o', 'primeiro', 'remédio'): 1,
#          ('o', 'primeiro', 'remédio', 'é'): 1,
#          ('primeiro', 'remédio', 'é', 'fugir'): 1,
#          ('remédio', 'é', 'fugir', 'a'): 1,
#          ('é', 'fugir', 'a', 'um'): 1,
#          ('fugir', 'a', 'um', 'prólogo'): 1,
#          ('a', 'um', 'prólogo', 'explícito'): 1,
#          ('um', 'prólogo', 'explícito', 'e'): 1,
#          ('prólogo', 'explícito', 'e', 'longo'): 1,
#          ('explícito', 'e', 'longo', '.'): 1,
#          ('e', 'longo', '.', '</s>'): 2,
#          ('longo', '.', '</s>', '<s>'): 3,
#          ('<s>', '<s>', 'O', 'melhor'): 4,
#          ('<s>', 'O', 'melhor', 'prólogo'): 1,
#          ('O', 'melhor', 'prólogo', 'é'): 1,
#          ('melhor', 'prólogo', 'é', 'o'): 1,
#          ('prólogo', 'é', 'o', 'que'): 1,
#          ('é', 'o', 'que', 'contém'): 1,
#          ('o', 'que', 'contém', 'menos'): 1,
#          ('que', 'contém', 'menos', 'coisas'): 1,
#          ('contém', 'menos', 'coisas', ','): 1,
#          ('menos', 'coisas', ',', 'ou'): 1,
#          ('coisas', ',', 'ou', 'o'): 1,
#          (',', 'ou', 'o', 'que'): 2,
#          ('ou', 'o', 'que', 'as'): 1,
#          ('o', 'que', 'as', 'diz'): 1,
#          ('que', 'as', 'diz', 'de'): 1,
#          ('as', 'diz', 'de', 'um'): 1,
#          ('diz', 'de', 'um', 'jeito'): 1,
#          ('de', 'um', 'jeito', 'obscuro'): 1,
#          ('um', 'jeito', 'obscuro', 'e'): 1,
#          ('jeito', 'obscuro', 'e', 'truncado'): 1,
#          ('obscuro', 'e', 'truncado', '.'): 1,
#          ('e', 'truncado', '.', '</s>'): 1,
#          ('truncado', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Conseguintemente'): 1,
#          ('<s>', '<s>', 'Conseguintemente', ','): 1,
#          ('<s>', 'Conseguintemente', ',', 'evito'): 1,
#          ('Conseguintemente', ',', 'evito', 'contar'): 1,
#          (',', 'evito', 'contar', 'o'): 1,
#          ('evito', 'contar', 'o', 'processo'): 1,
#          ('contar', 'o', 'processo', 'extraordinário'): 1,
#          ('o', 'processo', 'extraordinário', 'que'): 1,
#          ('processo', 'extraordinário', 'que', 'empreguei'): 1,
#          ('extraordinário', 'que', 'empreguei', 'na'): 1,
#          ('que', 'empreguei', 'na', 'composição'): 1,
#          ('empreguei', 'na', 'composição', 'destas'): 1,
#          ('na', 'composição', 'destas', 'Memórias'): 1,
#          ('composição', 'destas', 'Memórias', ','): 1,
#          ('destas', 'Memórias', ',', 'trabalhadas'): 1,
#          ('Memórias', ',', 'trabalhadas', 'cá'): 1,
#          (',', 'trabalhadas', 'cá', 'no'): 1,
#          ('trabalhadas', 'cá', 'no', 'outro'): 1,
#          ('cá', 'no', 'outro', 'mundo'): 1,
#          ('no', 'outro', 'mundo', '.'): 1,
#          ('outro', 'mundo', '.', '</s>'): 1,
#          ('mundo', '.', '</s>', '<s>'): 3,
#          ('<s>', '<s>', '<s>', 'Seria'): 3,
#          ('<s>', '<s>', 'Seria', 'curioso'): 1,
#          ('<s>', 'Seria', 'curioso', ','): 1,
#          ('Seria', 'curioso', ',', 'mas'): 1,
#          ('curioso', ',', 'mas', 'nimiamente'): 1,
#          (',', 'mas', 'nimiamente', 'extenso'): 1,
#          ('mas', 'nimiamente', 'extenso', ','): 1,
#          ('nimiamente', 'extenso', ',', 'e'): 1,
#          ('extenso', ',', 'e', 'aliás'): 1,
#          (',', 'e', 'aliás', 'desnecessário'): 1,
#          ('e', 'aliás', 'desnecessário', 'ao'): 1,
#          ('aliás', 'desnecessário', 'ao', 'entendimento'): 1,
#          ('desnecessário', 'ao', 'entendimento', 'da'): 1,
#          ('ao', 'entendimento', 'da', 'obra'): 1,
#          ('entendimento', 'da', 'obra', '.'): 1,
#          ('da', 'obra', '.', '</s>'): 1,
#          ('obra', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', 'A', 'obra'): 1,
#          ('<s>', 'A', 'obra', 'em'): 1,
#          ('A', 'obra', 'em', 'si'): 1,
#          ('obra', 'em', 'si', 'mesma'): 1,
#          ('em', 'si', 'mesma', 'é'): 1,
#          ('si', 'mesma', 'é', 'tudo'): 1,
#          ('mesma', 'é', 'tudo', ':'): 1,
#          ('é', 'tudo', ':', 'se'): 1,
#          ('tudo', ':', 'se', 'te'): 1,
#          (':', 'se', 'te', 'agradar'): 1,
#          ('se', 'te', 'agradar', ','): 1,
#          ('te', 'agradar', ',', 'fino'): 1,
#          ('agradar', ',', 'fino', 'leitor'): 1,
#          (',', 'fino', 'leitor', ','): 1,
#          ('fino', 'leitor', ',', 'pago'): 1,
#          ('leitor', ',', 'pago', '-'): 1,
#          (',', 'pago', '-', 'me'): 1,
#          ('pago', '-', 'me', 'da'): 1,
#          ('-', 'me', 'da', 'tarefa'): 1,
#          ('me', 'da', 'tarefa', ';'): 1,
#          ('da', 'tarefa', ';', 'se'): 1,
#          ('tarefa', ';', 'se', 'te'): 1,
#          (';', 'se', 'te', 'não'): 1,
#          ('se', 'te', 'não', 'agradar'): 1,
#          ('te', 'não', 'agradar', ','): 1,
#          ('não', 'agradar', ',', 'pago'): 1,
#          ('agradar', ',', 'pago', '-'): 1,
#          (',', 'pago', '-', 'te'): 1,
#          ('pago', '-', 'te', 'com'): 1,
#          ('-', 'te', 'com', 'um'): 1,
#          ('te', 'com', 'um', 'piparote'): 1,
#          ('com', 'um', 'piparote', ','): 1,
#          ('um', 'piparote', ',', 'e'): 1,
#          ('piparote', ',', 'e', 'adeus'): 1,
#          (',', 'e', 'adeus', '.'): 1,
#          ('e', 'adeus', '.', '</s>'): 1,
#          ('adeus', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Brás'): 1,
#          ('<s>', '<s>', 'Brás', 'Cubas'): 1,
#          ('<s>', 'Brás', 'Cubas', '.'): 1,
#          ('Brás', 'Cubas', '.', '</s>'): 6,
#          ('Cubas', '.', '</s>', '<s>'): 8,
#          ('<s>', '<s>', '<s>', 'CAPÍTULO'): 160,
#          ('<s>', '<s>', 'CAPÍTULO', 'PRIMEIRO'): 1,
#          ('<s>', 'CAPÍTULO', 'PRIMEIRO', '/'): 1,
#          ('CAPÍTULO', 'PRIMEIRO', '/', 'ÓBITO'): 1,
#          ('PRIMEIRO', '/', 'ÓBITO', 'DO'): 1,
#          ('/', 'ÓBITO', 'DO', 'AUTOR'): 1,
#          ('ÓBITO', 'DO', 'AUTOR', '</s>'): 1,
#          ('DO', 'AUTOR', '</s>', '<s>'): 1,
#          ('AUTOR', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Algum'): 3,
#          ('<s>', '<s>', 'Algum', 'tempo'): 2,
#          ('<s>', 'Algum', 'tempo', 'hesitei'): 1,
#          ('Algum', 'tempo', 'hesitei', 'se'): 1,
#          ('tempo', 'hesitei', 'se', 'devia'): 1,
#          ('hesitei', 'se', 'devia', 'abrir'): 1,
#          ('se', 'devia', 'abrir', 'estas'): 1,
#          ('devia', 'abrir', 'estas', 'memórias'): 1,
#          ('abrir', 'estas', 'memórias', 'pelo'): 1,
#          ('estas', 'memórias', 'pelo', 'princípio'): 1,
#          ('memórias', 'pelo', 'princípio', 'ou'): 1,
#          ('pelo', 'princípio', 'ou', 'pelo'): 1,
#          ('princípio', 'ou', 'pelo', 'fim'): 1,
#          ('ou', 'pelo', 'fim', ','): 1,
#          ('pelo', 'fim', ',', 'isto'): 1,
#          ('fim', ',', 'isto', 'é'): 1,
#          (',', 'isto', 'é', ','): 7,
#          ('isto', 'é', ',', 'se'): 1,
#          ('é', ',', 'se', 'poria'): 1,
#          (',', 'se', 'poria', 'em'): 1,
#          ('se', 'poria', 'em', 'primeiro'): 1,
#          ('poria', 'em', 'primeiro', 'lugar'): 1,
#          ('em', 'primeiro', 'lugar', 'o'): 1,
#          ('primeiro', 'lugar', 'o', 'meu'): 1,
#          ('lugar', 'o', 'meu', 'nascimento'): 1,
#          ('o', 'meu', 'nascimento', 'ou'): 1,
#          ('meu', 'nascimento', 'ou', 'a'): 1,
#          ('nascimento', 'ou', 'a', 'minha'): 1,
#          ('ou', 'a', 'minha', 'morte'): 1,
#          ('a', 'minha', 'morte', '.'): 1,
#          ('minha', 'morte', '.', '</s>'): 1,
#          ('morte', '.', '</s>', '<s>'): 8,
#          ('<s>', '<s>', '<s>', 'Suposto'): 1,
#          ('<s>', '<s>', 'Suposto', 'o'): 1,
#          ('<s>', 'Suposto', 'o', 'uso'): 1,
#          ('Suposto', 'o', 'uso', 'vulgar'): 1,
#          ('o', 'uso', 'vulgar', 'seja'): 1,
#          ('uso', 'vulgar', 'seja', 'começar'): 1,
#          ('vulgar', 'seja', 'começar', 'pelo'): 1,
#          ('seja', 'começar', 'pelo', 'nascimento'): 1,
#          ('começar', 'pelo', 'nascimento', ','): 1,
#          ('pelo', 'nascimento', ',', 'duas'): 1,
#          ('nascimento', ',', 'duas', 'considerações'): 1,
#          (',', 'duas', 'considerações', 'me'): 1,
#          ('duas', 'considerações', 'me', 'levaram'): 1,
#          ('considerações', 'me', 'levaram', 'a'): 1,
#          ('me', 'levaram', 'a', 'adotar'): 1,
#          ('levaram', 'a', 'adotar', 'diferente'): 1,
#          ('a', 'adotar', 'diferente', 'método'): 1,
#          ('adotar', 'diferente', 'método', ':'): 1,
#          ('diferente', 'método', ':', 'a'): 1,
#          ('método', ':', 'a', 'primeira'): 1,
#          (':', 'a', 'primeira', 'é'): 1,
#          ('a', 'primeira', 'é', 'que'): 1,
#          ('primeira', 'é', 'que', 'eu'): 1,
#          ('é', 'que', 'eu', 'não'): 2,
#          ('que', 'eu', 'não', 'sou'): 2,
#          ('eu', 'não', 'sou', 'propriamente'): 1,
#          ('não', 'sou', 'propriamente', 'um'): 1,
#          ('sou', 'propriamente', 'um', 'autor'): 1,
#          ('propriamente', 'um', 'autor', 'defunto'): 1,
#          ('um', 'autor', 'defunto', ','): 1,
#          ('autor', 'defunto', ',', 'mas'): 1,
#          ('defunto', ',', 'mas', 'um'): 1,
#          (',', 'mas', 'um', 'defunto'): 1,
#          ('mas', 'um', 'defunto', 'autor'): 1,
#          ('um', 'defunto', 'autor', ','): 1,
#          ('defunto', 'autor', ',', 'para'): 1,
#          ('autor', ',', 'para', 'quem'): 1,
#          (',', 'para', 'quem', 'a'): 1,
#          ('para', 'quem', 'a', 'campa'): 1,
#          ('quem', 'a', 'campa', 'foi'): 1,
#          ('a', 'campa', 'foi', 'outro'): 1,
#          ('campa', 'foi', 'outro', 'berço'): 1,
#          ('foi', 'outro', 'berço', ';'): 1,
#          ('outro', 'berço', ';', 'a'): 1,
#          ('berço', ';', 'a', 'segunda'): 1,
#          (';', 'a', 'segunda', 'é'): 1,
#          ('a', 'segunda', 'é', 'que'): 1,
#          ('segunda', 'é', 'que', 'o'): 1,
#          ('é', 'que', 'o', 'escrito'): 1,
#          ('que', 'o', 'escrito', 'ficaria'): 1,
#          ('o', 'escrito', 'ficaria', 'assim'): 1,
#          ('escrito', 'ficaria', 'assim', 'mais'): 1,
#          ('ficaria', 'assim', 'mais', 'galante'): 1,
#          ('assim', 'mais', 'galante', 'e'): 1,
#          ('mais', 'galante', 'e', 'mais'): 1,
#          ('galante', 'e', 'mais', 'novo'): 1,
#          ('e', 'mais', 'novo', '.'): 1,
#          ('mais', 'novo', '.', '</s>'): 1,
#          ('novo', '.', '</s>', '<s>'): 3,
#          ('<s>', '<s>', '<s>', 'Moisés'): 1,
#          ('<s>', '<s>', 'Moisés', ','): 1,
#          ('<s>', 'Moisés', ',', 'que'): 1,
#          ('Moisés', ',', 'que', 'também'): 1,
#          (',', 'que', 'também', 'contou'): 1,
#          ('que', 'também', 'contou', 'a'): 1,
#          ('também', 'contou', 'a', 'sua'): 1,
#          ('contou', 'a', 'sua', 'morte'): 1,
#          ('a', 'sua', 'morte', ','): 1,
#          ('sua', 'morte', ',', 'não'): 1,
#          ('morte', ',', 'não', 'a'): 1,
#          (',', 'não', 'a', 'pôs'): 1,
#          ('não', 'a', 'pôs', 'no'): 1,
#          ('a', 'pôs', 'no', 'intróito'): 1,
#          ('pôs', 'no', 'intróito', ','): 1,
#          ('no', 'intróito', ',', 'mas'): 1,
#          ('intróito', ',', 'mas', 'no'): 1,
#          (',', 'mas', 'no', 'cabo'): 1,
#          ('mas', 'no', 'cabo', ':'): 1,
#          ('no', 'cabo', ':', 'diferença'): 1,
#          ('cabo', ':', 'diferença', 'radical'): 1,
#          (':', 'diferença', 'radical', 'entre'): 1,
#          ('diferença', 'radical', 'entre', 'este'): 1,
#          ('radical', 'entre', 'este', 'livro'): 1,
#          ('entre', 'este', 'livro', 'e'): 1,
#          ('este', 'livro', 'e', 'o'): 2,
#          ('livro', 'e', 'o', 'Pentateuco'): 1,
#          ('e', 'o', 'Pentateuco', '.'): 1,
#          ('o', 'Pentateuco', '.', '</s>'): 1,
#          ('Pentateuco', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Dito'): 3,
#          ('<s>', '<s>', 'Dito', 'isto'): 2,
#          ('<s>', 'Dito', 'isto', ','): 2,
#          ('Dito', 'isto', ',', 'expirei'): 1,
#          ('isto', ',', 'expirei', 'às'): 1,
#          (',', 'expirei', 'às', 'duas'): 1,
#          ('expirei', 'às', 'duas', 'horas'): 1,
#          ('às', 'duas', 'horas', 'da'): 1,
#          ('duas', 'horas', 'da', 'tarde'): 2,
#          ('horas', 'da', 'tarde', 'de'): 1,
#          ('da', 'tarde', 'de', 'uma'): 1,
#          ('tarde', 'de', 'uma', 'sexta'): 1,
#          ('de', 'uma', 'sexta', '-'): 1,
#          ('uma', 'sexta', '-', 'feira'): 1,
#          ('sexta', '-', 'feira', 'do'): 1,
#          ('-', 'feira', 'do', 'mês'): 1,
#          ('feira', 'do', 'mês', 'de'): 1,
#          ('do', 'mês', 'de', 'agosto'): 1,
#          ('mês', 'de', 'agosto', 'de'): 1,
#          ('de', 'agosto', 'de', '1869'): 1,
#          ('agosto', 'de', '1869', ','): 1,
#          ('de', '1869', ',', 'na'): 1,
#          ('1869', ',', 'na', 'minha'): 1,
#          (',', 'na', 'minha', 'bela'): 1,
#          ('na', 'minha', 'bela', 'chácara'): 1,
#          ('minha', 'bela', 'chácara', 'de'): 1,
#          ('bela', 'chácara', 'de', 'Catumbi'): 1,
#          ('chácara', 'de', 'Catumbi', '.'): 1,
#          ('de', 'Catumbi', '.', '</s>'): 1,
#          ('Catumbi', '.', '</s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Tinha'): 18,
#          ('<s>', '<s>', 'Tinha', 'uns'): 1,
#          ('<s>', 'Tinha', 'uns', 'sessenta'): 1,
#          ('Tinha', 'uns', 'sessenta', 'e'): 1,
#          ('uns', 'sessenta', 'e', 'quatro'): 1,
#          ('sessenta', 'e', 'quatro', 'anos'): 2,
#          ('e', 'quatro', 'anos', ','): 2,
#          ('quatro', 'anos', ',', 'rijos'): 1,
#          ('anos', ',', 'rijos', 'e'): 1,
#          (',', 'rijos', 'e', 'prósperos'): 1,
#          ('rijos', 'e', 'prósperos', ','): 1,
#          ('e', 'prósperos', ',', 'era'): 1,
#          ('prósperos', ',', 'era', 'solteiro'): 1,
#          (',', 'era', 'solteiro', ','): 1,
#          ('era', 'solteiro', ',', 'possuía'): 1,
#          ('solteiro', ',', 'possuía', 'cerca'): 1,
#          (',', 'possuía', 'cerca', 'de'): 1,
#          ('possuía', 'cerca', 'de', 'trezentos'): 1,
#          ('cerca', 'de', 'trezentos', 'contos'): 1,
#          ('de', 'trezentos', 'contos', 'e'): 1,
#          ('trezentos', 'contos', 'e', 'fui'): 1,
#          ('contos', 'e', 'fui', 'acompanhado'): 1,
#          ('e', 'fui', 'acompanhado', 'ao'): 1,
#          ('fui', 'acompanhado', 'ao', 'cemitério'): 1,
#          ('acompanhado', 'ao', 'cemitério', 'por'): 1,
#          ('ao', 'cemitério', 'por', 'onze'): 1,
#          ('cemitério', 'por', 'onze', 'amigos'): 1,
#          ('por', 'onze', 'amigos', '.'): 1,
#          ('onze', 'amigos', '.', '</s>'): 1,
#          ('amigos', '.', '</s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'Onze'): 1,
#          ('<s>', '<s>', 'Onze', 'amigos'): 1,
#          ('<s>', 'Onze', 'amigos', '!'): 1,
#          ('Onze', 'amigos', '!', '</s>'): 1,
#          ('amigos', '!', '</s>', '<s>'): 2,
#          ('!', '</s>', '<s>', '<s>'): 295,
#          ('<s>', '<s>', '<s>', 'Verdade'): 5,
#          ('<s>', '<s>', 'Verdade', 'é'): 5,
#          ('<s>', 'Verdade', 'é', 'que'): 5,
#          ('Verdade', 'é', 'que', 'não'): 1,
#          ('é', 'que', 'não', 'houve'): 1,
#          ('que', 'não', 'houve', 'cartas'): 1,
#          ('não', 'houve', 'cartas', 'nem'): 1,
#          ('houve', 'cartas', 'nem', 'anúncios'): 1,
#          ('cartas', 'nem', 'anúncios', '.'): 1,
#          ('nem', 'anúncios', '.', '</s>'): 1,
#          ('anúncios', '.', '</s>', '<s>'): 1,
#          ('<s>', 'Acresce', 'que', 'chovia'): 1,
#          ('Acresce', 'que', 'chovia', '\x97'): 1,
#          ('que', 'chovia', '\x97', 'peneirava'): 1,
#          ('chovia', '\x97', 'peneirava', 'uma'): 1,
#          ('\x97', 'peneirava', 'uma', 'chuvinha'): 1,
#          ('peneirava', 'uma', 'chuvinha', 'miúda'): 1,
#          ('uma', 'chuvinha', 'miúda', ','): 1,
#          ('chuvinha', 'miúda', ',', 'triste'): 1,
#          ('miúda', ',', 'triste', 'e'): 1,
#          (',', 'triste', 'e', 'constante'): 1,
#          ('triste', 'e', 'constante', ','): 1,
#          ('e', 'constante', ',', 'tão'): 1,
#          ('constante', ',', 'tão', 'constante'): 1,
#          (',', 'tão', 'constante', 'e'): 1,
#          ('tão', 'constante', 'e', 'tão'): 1,
#          ('constante', 'e', 'tão', 'triste'): 1,
#          ('e', 'tão', 'triste', ','): 2,
#          ('tão', 'triste', ',', 'que'): 2,
#          ('triste', ',', 'que', 'levou'): 1,
#          (',', 'que', 'levou', 'um'): 1,
#          ('que', 'levou', 'um', 'daqueles'): 1,
#          ('levou', 'um', 'daqueles', 'fiéis'): 1,
#          ('um', 'daqueles', 'fiéis', 'da'): 1,
#          ...})

# %%
count_fivegram = Counter(fivegrams)
count_fivegram
# Out:
# Counter({('<s>', '<s>', '<s>', '<s>', 'Romance'): 1,
#          ('<s>', '<s>', '<s>', 'Romance', ','): 1,
#          ('<s>', '<s>', 'Romance', ',', 'Memórias'): 1,
#          ('<s>', 'Romance', ',', 'Memórias', 'Póstumas'): 1,
#          ('Romance', ',', 'Memórias', 'Póstumas', 'de'): 1,
#          (',', 'Memórias', 'Póstumas', 'de', 'Brás'): 1,
#          ('Memórias', 'Póstumas', 'de', 'Brás', 'Cubas'): 4,
#          ('Póstumas', 'de', 'Brás', 'Cubas', ','): 1,
#          ('de', 'Brás', 'Cubas', ',', '1880'): 1,
#          ('Brás', 'Cubas', ',', '1880', '</s>'): 1,
#          ('Cubas', ',', '1880', '</s>', '<s>'): 1,
#          (',', '1880', '</s>', '<s>', '<s>'): 1,
#          ('1880', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('</s>', '<s>', '<s>', '<s>', '<s>'): 3821,
#          ('<s>', '<s>', '<s>', '<s>', 'Memórias'): 1,
#          ('<s>', '<s>', '<s>', 'Memórias', 'Póstumas'): 1,
#          ('<s>', '<s>', 'Memórias', 'Póstumas', 'de'): 1,
#          ('<s>', 'Memórias', 'Póstumas', 'de', 'Brás'): 1,
#          ('Póstumas', 'de', 'Brás', 'Cubas', '</s>'): 1,
#          ('de', 'Brás', 'Cubas', '</s>', '<s>'): 1,
#          ('Brás', 'Cubas', '</s>', '<s>', '<s>'): 1,
#          ('Cubas', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Texto'): 1,
#          ('<s>', '<s>', '<s>', 'Texto', '-'): 1,
#          ('<s>', '<s>', 'Texto', '-', 'fonte'): 1,
#          ('<s>', 'Texto', '-', 'fonte', ':'): 1,
#          ('Texto', '-', 'fonte', ':', 'Obra'): 1,
#          ('-', 'fonte', ':', 'Obra', 'Completa'): 1,
#          ('fonte', ':', 'Obra', 'Completa', ','): 1,
#          (':', 'Obra', 'Completa', ',', 'Machado'): 1,
#          ('Obra', 'Completa', ',', 'Machado', 'de'): 1,
#          ('Completa', ',', 'Machado', 'de', 'Assis'): 1,
#          (',', 'Machado', 'de', 'Assis', ','): 1,
#          ('Machado', 'de', 'Assis', ',', 'Rio'): 1,
#          ('de', 'Assis', ',', 'Rio', 'de'): 1,
#          ('Assis', ',', 'Rio', 'de', 'Janeiro'): 1,
#          (',', 'Rio', 'de', 'Janeiro', ':'): 1,
#          ('Rio', 'de', 'Janeiro', ':', 'Editora'): 1,
#          ('de', 'Janeiro', ':', 'Editora', 'Nova'): 1,
#          ('Janeiro', ':', 'Editora', 'Nova', 'Aguilar'): 1,
#          (':', 'Editora', 'Nova', 'Aguilar', ','): 1,
#          ('Editora', 'Nova', 'Aguilar', ',', '1994'): 1,
#          ('Nova', 'Aguilar', ',', '1994', '.'): 1,
#          ('Aguilar', ',', '1994', '.', '</s>'): 1,
#          (',', '1994', '.', '</s>', '<s>'): 1,
#          ('1994', '.', '</s>', '<s>', '<s>'): 1,
#          ('.', '</s>', '<s>', '<s>', '<s>'): 2813,
#          ('<s>', '<s>', '<s>', '<s>', 'Publicado'): 1,
#          ('<s>', '<s>', '<s>', 'Publicado', 'originalmente'): 1,
#          ('<s>', '<s>', 'Publicado', 'originalmente', 'em'): 1,
#          ('<s>', 'Publicado', 'originalmente', 'em', 'folhetins'): 1,
#          ('Publicado', 'originalmente', 'em', 'folhetins', ','): 1,
#          ('originalmente', 'em', 'folhetins', ',', 'a'): 1,
#          ('em', 'folhetins', ',', 'a', 'partir'): 1,
#          ('folhetins', ',', 'a', 'partir', 'de'): 1,
#          (',', 'a', 'partir', 'de', 'março'): 1,
#          ('a', 'partir', 'de', 'março', 'de'): 1,
#          ('partir', 'de', 'março', 'de', '1880'): 1,
#          ('de', 'março', 'de', '1880', ','): 1,
#          ('março', 'de', '1880', ',', 'na'): 1,
#          ('de', '1880', ',', 'na', 'Revista'): 1,
#          ('1880', ',', 'na', 'Revista', 'Brasileira'): 1,
#          (',', 'na', 'Revista', 'Brasileira', '.'): 1,
#          ('na', 'Revista', 'Brasileira', '.', '</s>'): 1,
#          ('Revista', 'Brasileira', '.', '</s>', '<s>'): 1,
#          ('Brasileira', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Ao'): 33,
#          ('<s>', '<s>', '<s>', 'Ao', 'verme'): 1,
#          ('<s>', '<s>', 'Ao', 'verme', 'que'): 1,
#          ('<s>', 'Ao', 'verme', 'que', 'primeiro'): 1,
#          ('Ao', 'verme', 'que', 'primeiro', 'roeu'): 1,
#          ('verme', 'que', 'primeiro', 'roeu', 'as'): 1,
#          ('que', 'primeiro', 'roeu', 'as', 'frias'): 1,
#          ('primeiro', 'roeu', 'as', 'frias', 'carnes'): 1,
#          ('roeu', 'as', 'frias', 'carnes', 'do'): 1,
#          ('as', 'frias', 'carnes', 'do', 'meu'): 1,
#          ('frias', 'carnes', 'do', 'meu', 'cadáver'): 1,
#          ('carnes', 'do', 'meu', 'cadáver', '</s>'): 1,
#          ('do', 'meu', 'cadáver', '</s>', '<s>'): 1,
#          ('meu', 'cadáver', '</s>', '<s>', '<s>'): 1,
#          ('cadáver', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'dedico'): 1,
#          ('<s>', '<s>', '<s>', 'dedico', 'como'): 1,
#          ('<s>', '<s>', 'dedico', 'como', 'saudosa'): 1,
#          ('<s>', 'dedico', 'como', 'saudosa', 'lembrança'): 1,
#          ('dedico', 'como', 'saudosa', 'lembrança', '</s>'): 1,
#          ('como', 'saudosa', 'lembrança', '</s>', '<s>'): 1,
#          ('saudosa', 'lembrança', '</s>', '<s>', '<s>'): 1,
#          ('lembrança', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'estas'): 1,
#          ('<s>', '<s>', '<s>', 'estas', 'Memórias'): 1,
#          ('<s>', '<s>', 'estas', 'Memórias', 'Póstumas'): 1,
#          ('<s>', 'estas', 'Memórias', 'Póstumas', '</s>'): 1,
#          ('estas', 'Memórias', 'Póstumas', '</s>', '<s>'): 1,
#          ('Memórias', 'Póstumas', '</s>', '<s>', '<s>'): 1,
#          ('Póstumas', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Prólogo'): 1,
#          ('<s>', '<s>', '<s>', 'Prólogo', 'da'): 1,
#          ('<s>', '<s>', 'Prólogo', 'da', 'terceira'): 1,
#          ('<s>', 'Prólogo', 'da', 'terceira', 'edição'): 1,
#          ('Prólogo', 'da', 'terceira', 'edição', '</s>'): 1,
#          ('da', 'terceira', 'edição', '</s>', '<s>'): 1,
#          ('terceira', 'edição', '</s>', '<s>', '<s>'): 1,
#          ('edição', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'A'): 125,
#          ('<s>', '<s>', '<s>', 'A', 'primeira'): 2,
#          ('<s>', '<s>', 'A', 'primeira', 'edição'): 1,
#          ('<s>', 'A', 'primeira', 'edição', 'destas'): 1,
#          ('A', 'primeira', 'edição', 'destas', 'Memórias'): 1,
#          ('primeira', 'edição', 'destas', 'Memórias', 'Póstumas'): 1,
#          ('edição', 'destas', 'Memórias', 'Póstumas', 'de'): 1,
#          ('destas', 'Memórias', 'Póstumas', 'de', 'Brás'): 1,
#          ('Póstumas', 'de', 'Brás', 'Cubas', 'foi'): 1,
#          ('de', 'Brás', 'Cubas', 'foi', 'feita'): 1,
#          ('Brás', 'Cubas', 'foi', 'feita', 'aos'): 1,
#          ('Cubas', 'foi', 'feita', 'aos', 'pedaços'): 1,
#          ('foi', 'feita', 'aos', 'pedaços', 'na'): 1,
#          ('feita', 'aos', 'pedaços', 'na', 'Revista'): 1,
#          ('aos', 'pedaços', 'na', 'Revista', 'Brasileira'): 1,
#          ('pedaços', 'na', 'Revista', 'Brasileira', ','): 1,
#          ('na', 'Revista', 'Brasileira', ',', 'pelos'): 1,
#          ('Revista', 'Brasileira', ',', 'pelos', 'anos'): 1,
#          ('Brasileira', ',', 'pelos', 'anos', 'de'): 1,
#          (',', 'pelos', 'anos', 'de', '1880'): 1,
#          ('pelos', 'anos', 'de', '1880', '.'): 1,
#          ('anos', 'de', '1880', '.', '</s>'): 1,
#          ('de', '1880', '.', '</s>', '<s>'): 1,
#          ('1880', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Postas'): 1,
#          ('<s>', '<s>', '<s>', 'Postas', 'mais'): 1,
#          ('<s>', '<s>', 'Postas', 'mais', 'tarde'): 1,
#          ('<s>', 'Postas', 'mais', 'tarde', 'em'): 1,
#          ('Postas', 'mais', 'tarde', 'em', 'livro'): 1,
#          ('mais', 'tarde', 'em', 'livro', ','): 1,
#          ('tarde', 'em', 'livro', ',', 'corrigi'): 1,
#          ('em', 'livro', ',', 'corrigi', 'o'): 1,
#          ('livro', ',', 'corrigi', 'o', 'texto'): 1,
#          (',', 'corrigi', 'o', 'texto', 'em'): 1,
#          ('corrigi', 'o', 'texto', 'em', 'vários'): 1,
#          ('o', 'texto', 'em', 'vários', 'lugares'): 1,
#          ('texto', 'em', 'vários', 'lugares', '.'): 1,
#          ('em', 'vários', 'lugares', '.', '</s>'): 1,
#          ('vários', 'lugares', '.', '</s>', '<s>'): 1,
#          ('lugares', '.', '</s>', '<s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', '<s>', 'Agora'): 18,
#          ('<s>', '<s>', '<s>', 'Agora', 'que'): 1,
#          ('<s>', '<s>', 'Agora', 'que', 'tive'): 1,
#          ('<s>', 'Agora', 'que', 'tive', 'de'): 1,
#          ('Agora', 'que', 'tive', 'de', 'o'): 1,
#          ('que', 'tive', 'de', 'o', 'rever'): 1,
#          ('tive', 'de', 'o', 'rever', 'para'): 1,
#          ('de', 'o', 'rever', 'para', 'a'): 1,
#          ('o', 'rever', 'para', 'a', 'terceira'): 1,
#          ('rever', 'para', 'a', 'terceira', 'edição'): 1,
#          ('para', 'a', 'terceira', 'edição', ','): 1,
#          ('a', 'terceira', 'edição', ',', 'emendei'): 1,
#          ('terceira', 'edição', ',', 'emendei', 'ainda'): 1,
#          ('edição', ',', 'emendei', 'ainda', 'alguma'): 1,
#          (',', 'emendei', 'ainda', 'alguma', 'coisa'): 1,
#          ('emendei', 'ainda', 'alguma', 'coisa', 'e'): 1,
#          ('ainda', 'alguma', 'coisa', 'e', 'suprimi'): 1,
#          ('alguma', 'coisa', 'e', 'suprimi', 'duas'): 1,
#          ('coisa', 'e', 'suprimi', 'duas', 'ou'): 1,
#          ('e', 'suprimi', 'duas', 'ou', 'três'): 1,
#          ('suprimi', 'duas', 'ou', 'três', 'dúzias'): 1,
#          ('duas', 'ou', 'três', 'dúzias', 'de'): 1,
#          ('ou', 'três', 'dúzias', 'de', 'linhas'): 1,
#          ('três', 'dúzias', 'de', 'linhas', '.'): 1,
#          ('dúzias', 'de', 'linhas', '.', '</s>'): 1,
#          ('de', 'linhas', '.', '</s>', '<s>'): 1,
#          ('linhas', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Assim'): 12,
#          ('<s>', '<s>', '<s>', 'Assim', 'composta'): 1,
#          ('<s>', '<s>', 'Assim', 'composta', ','): 1,
#          ('<s>', 'Assim', 'composta', ',', 'sai'): 1,
#          ('Assim', 'composta', ',', 'sai', 'novamente'): 1,
#          ('composta', ',', 'sai', 'novamente', 'à'): 1,
#          (',', 'sai', 'novamente', 'à', 'luz'): 1,
#          ('sai', 'novamente', 'à', 'luz', 'esta'): 1,
#          ('novamente', 'à', 'luz', 'esta', 'obra'): 1,
#          ('à', 'luz', 'esta', 'obra', 'que'): 1,
#          ('luz', 'esta', 'obra', 'que', 'alguma'): 1,
#          ('esta', 'obra', 'que', 'alguma', 'benevolência'): 1,
#          ('obra', 'que', 'alguma', 'benevolência', 'parece'): 1,
#          ('que', 'alguma', 'benevolência', 'parece', 'ter'): 1,
#          ('alguma', 'benevolência', 'parece', 'ter', 'encontrado'): 1,
#          ('benevolência', 'parece', 'ter', 'encontrado', 'no'): 1,
#          ('parece', 'ter', 'encontrado', 'no', 'público'): 1,
#          ('ter', 'encontrado', 'no', 'público', '.'): 1,
#          ('encontrado', 'no', 'público', '.', '</s>'): 1,
#          ('no', 'público', '.', '</s>', '<s>'): 1,
#          ('público', '.', '</s>', '<s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', '<s>', 'Capistrano'): 1,
#          ('<s>', '<s>', '<s>', 'Capistrano', 'de'): 1,
#          ('<s>', '<s>', 'Capistrano', 'de', 'Abreu'): 1,
#          ('<s>', 'Capistrano', 'de', 'Abreu', ','): 1,
#          ('Capistrano', 'de', 'Abreu', ',', 'noticiando'): 1,
#          ('de', 'Abreu', ',', 'noticiando', 'a'): 1,
#          ('Abreu', ',', 'noticiando', 'a', 'publicação'): 1,
#          (',', 'noticiando', 'a', 'publicação', 'do'): 1,
#          ('noticiando', 'a', 'publicação', 'do', 'livro'): 1,
#          ('a', 'publicação', 'do', 'livro', ','): 1,
#          ('publicação', 'do', 'livro', ',', 'perguntava'): 1,
#          ('do', 'livro', ',', 'perguntava', ':'): 1,
#          ('livro', ',', 'perguntava', ':', '\x93'): 1,
#          (',', 'perguntava', ':', '\x93', 'As'): 1,
#          ('perguntava', ':', '\x93', 'As', 'Memórias'): 1,
#          (':', '\x93', 'As', 'Memórias', 'Póstumas'): 1,
#          ('\x93', 'As', 'Memórias', 'Póstumas', 'de'): 1,
#          ('As', 'Memórias', 'Póstumas', 'de', 'Brás'): 1,
#          ('Póstumas', 'de', 'Brás', 'Cubas', 'são'): 1,
#          ('de', 'Brás', 'Cubas', 'são', 'um'): 1,
#          ('Brás', 'Cubas', 'são', 'um', 'romance'): 1,
#          ('Cubas', 'são', 'um', 'romance', '?\x94'): 1,
#          ('são', 'um', 'romance', '?\x94', 'Macedo'): 1,
#          ('um', 'romance', '?\x94', 'Macedo', 'Soares'): 1,
#          ('romance', '?\x94', 'Macedo', 'Soares', ','): 1,
#          ('?\x94', 'Macedo', 'Soares', ',', 'em'): 1,
#          ('Macedo', 'Soares', ',', 'em', 'carta'): 1,
#          ('Soares', ',', 'em', 'carta', 'que'): 1,
#          (',', 'em', 'carta', 'que', 'me'): 1,
#          ('em', 'carta', 'que', 'me', 'escreveu'): 1,
#          ('carta', 'que', 'me', 'escreveu', 'por'): 1,
#          ('que', 'me', 'escreveu', 'por', 'esse'): 1,
#          ('me', 'escreveu', 'por', 'esse', 'tempo'): 1,
#          ('escreveu', 'por', 'esse', 'tempo', ','): 1,
#          ('por', 'esse', 'tempo', ',', 'recordava'): 1,
#          ('esse', 'tempo', ',', 'recordava', 'amigamente'): 1,
#          ('tempo', ',', 'recordava', 'amigamente', 'as'): 1,
#          (',', 'recordava', 'amigamente', 'as', 'Viagens'): 1,
#          ('recordava', 'amigamente', 'as', 'Viagens', 'na'): 1,
#          ('amigamente', 'as', 'Viagens', 'na', 'minha'): 1,
#          ('as', 'Viagens', 'na', 'minha', 'terra'): 1,
#          ('Viagens', 'na', 'minha', 'terra', '.'): 1,
#          ('na', 'minha', 'terra', '.', '</s>'): 1,
#          ('minha', 'terra', '.', '</s>', '<s>'): 1,
#          ('terra', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', 'Ao', 'primeiro'): 1,
#          ('<s>', '<s>', 'Ao', 'primeiro', 'respondia'): 1,
#          ('<s>', 'Ao', 'primeiro', 'respondia', 'já'): 1,
#          ('Ao', 'primeiro', 'respondia', 'já', 'o'): 1,
#          ('primeiro', 'respondia', 'já', 'o', 'defunto'): 1,
#          ('respondia', 'já', 'o', 'defunto', 'Brás'): 1,
#          ('já', 'o', 'defunto', 'Brás', 'Cubas'): 1,
#          ('o', 'defunto', 'Brás', 'Cubas', '('): 1,
#          ('defunto', 'Brás', 'Cubas', '(', 'como'): 1,
#          ('Brás', 'Cubas', '(', 'como', 'o'): 1,
#          ('Cubas', '(', 'como', 'o', 'leitor'): 1,
#          ('(', 'como', 'o', 'leitor', 'viu'): 1,
#          ('como', 'o', 'leitor', 'viu', 'e'): 1,
#          ('o', 'leitor', 'viu', 'e', 'verá'): 1,
#          ('leitor', 'viu', 'e', 'verá', 'no'): 1,
#          ('viu', 'e', 'verá', 'no', 'prólogo'): 1,
#          ('e', 'verá', 'no', 'prólogo', 'dele'): 1,
#          ('verá', 'no', 'prólogo', 'dele', 'que'): 1,
#          ('no', 'prólogo', 'dele', 'que', 'vai'): 1,
#          ('prólogo', 'dele', 'que', 'vai', 'adiante'): 1,
#          ('dele', 'que', 'vai', 'adiante', ')'): 1,
#          ('que', 'vai', 'adiante', ')', 'que'): 1,
#          ('vai', 'adiante', ')', 'que', 'sim'): 1,
#          ('adiante', ')', 'que', 'sim', 'e'): 1,
#          (')', 'que', 'sim', 'e', 'que'): 1,
#          ('que', 'sim', 'e', 'que', 'não'): 1,
#          ('sim', 'e', 'que', 'não', ','): 1,
#          ('e', 'que', 'não', ',', 'que'): 1,
#          ('que', 'não', ',', 'que', 'era'): 1,
#          ('não', ',', 'que', 'era', 'romance'): 1,
#          (',', 'que', 'era', 'romance', 'para'): 1,
#          ('que', 'era', 'romance', 'para', 'uns'): 1,
#          ('era', 'romance', 'para', 'uns', 'e'): 1,
#          ('romance', 'para', 'uns', 'e', 'não'): 1,
#          ('para', 'uns', 'e', 'não', 'o'): 1,
#          ('uns', 'e', 'não', 'o', 'era'): 1,
#          ('e', 'não', 'o', 'era', 'para'): 1,
#          ('não', 'o', 'era', 'para', 'outros'): 1,
#          ('o', 'era', 'para', 'outros', '.'): 1,
#          ('era', 'para', 'outros', '.', '</s>'): 1,
#          ('para', 'outros', '.', '</s>', '<s>'): 1,
#          ('outros', '.', '</s>', '<s>', '<s>'): 10,
#          ('<s>', '<s>', '<s>', '<s>', 'Quanto'): 16,
#          ('<s>', '<s>', '<s>', 'Quanto', 'ao'): 4,
#          ('<s>', '<s>', 'Quanto', 'ao', 'segundo'): 1,
#          ('<s>', 'Quanto', 'ao', 'segundo', ','): 1,
#          ('Quanto', 'ao', 'segundo', ',', 'assim'): 1,
#          ('ao', 'segundo', ',', 'assim', 'se'): 1,
#          ('segundo', ',', 'assim', 'se', 'explicou'): 1,
#          (',', 'assim', 'se', 'explicou', 'o'): 1,
#          ('assim', 'se', 'explicou', 'o', 'finado'): 1,
#          ('se', 'explicou', 'o', 'finado', ':'): 1,
#          ('explicou', 'o', 'finado', ':', '\x93'): 1,
#          ('o', 'finado', ':', '\x93', 'Trata'): 1,
#          ('finado', ':', '\x93', 'Trata', '-'): 1,
#          (':', '\x93', 'Trata', '-', 'se'): 1,
#          ('\x93', 'Trata', '-', 'se', 'de'): 1,
#          ('Trata', '-', 'se', 'de', 'uma'): 1,
#          ('-', 'se', 'de', 'uma', 'obra'): 1,
#          ('se', 'de', 'uma', 'obra', 'difusa'): 1,
#          ('de', 'uma', 'obra', 'difusa', ','): 2,
#          ('uma', 'obra', 'difusa', ',', 'na'): 2,
#          ('obra', 'difusa', ',', 'na', 'qual'): 2,
#          ('difusa', ',', 'na', 'qual', 'eu'): 2,
#          (',', 'na', 'qual', 'eu', ','): 2,
#          ('na', 'qual', 'eu', ',', 'Brás'): 2,
#          ('qual', 'eu', ',', 'Brás', 'Cubas'): 2,
#          ('eu', ',', 'Brás', 'Cubas', ','): 3,
#          (',', 'Brás', 'Cubas', ',', 'se'): 2,
#          ('Brás', 'Cubas', ',', 'se', 'adotei'): 2,
#          ('Cubas', ',', 'se', 'adotei', 'a'): 2,
#          (',', 'se', 'adotei', 'a', 'forma'): 2,
#          ('se', 'adotei', 'a', 'forma', 'livre'): 2,
#          ('adotei', 'a', 'forma', 'livre', 'de'): 2,
#          ('a', 'forma', 'livre', 'de', 'um'): 2,
#          ('forma', 'livre', 'de', 'um', 'Sterne'): 2,
#          ('livre', 'de', 'um', 'Sterne', 'ou'): 1,
#          ('de', 'um', 'Sterne', 'ou', 'de'): 1,
#          ('um', 'Sterne', 'ou', 'de', 'um'): 1,
#          ('Sterne', 'ou', 'de', 'um', 'Xavier'): 1,
#          ('ou', 'de', 'um', 'Xavier', 'de'): 2,
#          ('de', 'um', 'Xavier', 'de', 'Maistre'): 2,
#          ('um', 'Xavier', 'de', 'Maistre', ','): 2,
#          ('Xavier', 'de', 'Maistre', ',', 'não'): 2,
#          ('de', 'Maistre', ',', 'não', 'sei'): 2,
#          ('Maistre', ',', 'não', 'sei', 'se'): 2,
#          (',', 'não', 'sei', 'se', 'lhe'): 2,
#          ('não', 'sei', 'se', 'lhe', 'meti'): 2,
#          ('sei', 'se', 'lhe', 'meti', 'algumas'): 2,
#          ('se', 'lhe', 'meti', 'algumas', 'rabugens'): 2,
#          ('lhe', 'meti', 'algumas', 'rabugens', 'de'): 2,
#          ('meti', 'algumas', 'rabugens', 'de', 'pessimismo'): 2,
#          ('algumas', 'rabugens', 'de', 'pessimismo', '.\x94'): 1,
#          ('rabugens', 'de', 'pessimismo', '.\x94', 'Toda'): 1,
#          ('de', 'pessimismo', '.\x94', 'Toda', 'essa'): 1,
#          ('pessimismo', '.\x94', 'Toda', 'essa', 'gente'): 1,
#          ('.\x94', 'Toda', 'essa', 'gente', 'viajou'): 1,
#          ('Toda', 'essa', 'gente', 'viajou', ':'): 1,
#          ('essa', 'gente', 'viajou', ':', 'Xavier'): 1,
#          ('gente', 'viajou', ':', 'Xavier', 'de'): 1,
#          ('viajou', ':', 'Xavier', 'de', 'Maistre'): 1,
#          (':', 'Xavier', 'de', 'Maistre', 'à'): 1,
#          ('Xavier', 'de', 'Maistre', 'à', 'roda'): 1,
#          ('de', 'Maistre', 'à', 'roda', 'do'): 1,
#          ('Maistre', 'à', 'roda', 'do', 'quarto'): 1,
#          ('à', 'roda', 'do', 'quarto', ','): 1,
#          ('roda', 'do', 'quarto', ',', 'Garret'): 1,
#          ('do', 'quarto', ',', 'Garret', 'na'): 1,
#          ('quarto', ',', 'Garret', 'na', 'terra'): 1,
#          (',', 'Garret', 'na', 'terra', 'dele'): 1,
#          ('Garret', 'na', 'terra', 'dele', ','): 1,
#          ('na', 'terra', 'dele', ',', 'Sterne'): 1,
#          ('terra', 'dele', ',', 'Sterne', 'na'): 1,
#          ('dele', ',', 'Sterne', 'na', 'terra'): 1,
#          (',', 'Sterne', 'na', 'terra', 'dos'): 1,
#          ('Sterne', 'na', 'terra', 'dos', 'outros'): 1,
#          ('na', 'terra', 'dos', 'outros', '.'): 1,
#          ('terra', 'dos', 'outros', '.', '</s>'): 1,
#          ('dos', 'outros', '.', '</s>', '<s>'): 4,
#          ('<s>', '<s>', '<s>', '<s>', 'De'): 31,
#          ('<s>', '<s>', '<s>', 'De', 'Brás'): 1,
#          ('<s>', '<s>', 'De', 'Brás', 'Cubas'): 1,
#          ('<s>', 'De', 'Brás', 'Cubas', 'se'): 1,
#          ('De', 'Brás', 'Cubas', 'se', 'pode'): 1,
#          ('Brás', 'Cubas', 'se', 'pode', 'dizer'): 1,
#          ('Cubas', 'se', 'pode', 'dizer', 'que'): 1,
#          ('se', 'pode', 'dizer', 'que', 'viajou'): 1,
#          ('pode', 'dizer', 'que', 'viajou', 'à'): 1,
#          ('dizer', 'que', 'viajou', 'à', 'roda'): 1,
#          ('que', 'viajou', 'à', 'roda', 'da'): 1,
#          ('viajou', 'à', 'roda', 'da', 'vida'): 1,
#          ('à', 'roda', 'da', 'vida', '.'): 1,
#          ('roda', 'da', 'vida', '.', '</s>'): 1,
#          ('da', 'vida', '.', '</s>', '<s>'): 4,
#          ('vida', '.', '</s>', '<s>', '<s>'): 12,
#          ('<s>', '<s>', '<s>', '<s>', 'O'): 110,
#          ('<s>', '<s>', '<s>', 'O', 'que'): 14,
#          ('<s>', '<s>', 'O', 'que', 'faz'): 1,
#          ('<s>', 'O', 'que', 'faz', 'do'): 1,
#          ('O', 'que', 'faz', 'do', 'meu'): 1,
#          ('que', 'faz', 'do', 'meu', 'Brás'): 1,
#          ('faz', 'do', 'meu', 'Brás', 'Cubas'): 1,
#          ('do', 'meu', 'Brás', 'Cubas', 'um'): 1,
#          ('meu', 'Brás', 'Cubas', 'um', 'autor'): 1,
#          ('Brás', 'Cubas', 'um', 'autor', 'particular'): 1,
#          ('Cubas', 'um', 'autor', 'particular', 'é'): 1,
#          ('um', 'autor', 'particular', 'é', 'o'): 1,
#          ('autor', 'particular', 'é', 'o', 'que'): 1,
#          ('particular', 'é', 'o', 'que', 'ele'): 1,
#          ('é', 'o', 'que', 'ele', 'chama'): 1,
#          ('o', 'que', 'ele', 'chama', '\x93'): 1,
#          ('que', 'ele', 'chama', '\x93', 'rabugens'): 1,
#          ('ele', 'chama', '\x93', 'rabugens', 'de'): 1,
#          ('chama', '\x93', 'rabugens', 'de', 'pessimismo'): 1,
#          ('\x93', 'rabugens', 'de', 'pessimismo', '\x94.'): 1,
#          ('rabugens', 'de', 'pessimismo', '\x94.', '</s>'): 1,
#          ('de', 'pessimismo', '\x94.', '</s>', '<s>'): 1,
#          ('pessimismo', '\x94.', '</s>', '<s>', '<s>'): 1,
#          ('\x94.', '</s>', '<s>', '<s>', '<s>'): 12,
#          ('<s>', '<s>', '<s>', '<s>', 'Há'): 9,
#          ('<s>', '<s>', '<s>', 'Há', 'na'): 1,
#          ('<s>', '<s>', 'Há', 'na', 'alma'): 1,
#          ('<s>', 'Há', 'na', 'alma', 'deste'): 1,
#          ('Há', 'na', 'alma', 'deste', 'livro'): 1,
#          ('na', 'alma', 'deste', 'livro', ','): 1,
#          ('alma', 'deste', 'livro', ',', 'por'): 1,
#          ('deste', 'livro', ',', 'por', 'mais'): 1,
#          ('livro', ',', 'por', 'mais', 'risonho'): 1,
#          (',', 'por', 'mais', 'risonho', 'que'): 1,
#          ('por', 'mais', 'risonho', 'que', 'pareça'): 1,
#          ('mais', 'risonho', 'que', 'pareça', ','): 1,
#          ('risonho', 'que', 'pareça', ',', 'um'): 1,
#          ('que', 'pareça', ',', 'um', 'sentimento'): 1,
#          ('pareça', ',', 'um', 'sentimento', 'amargo'): 1,
#          (',', 'um', 'sentimento', 'amargo', 'e'): 1,
#          ('um', 'sentimento', 'amargo', 'e', 'áspero'): 1,
#          ('sentimento', 'amargo', 'e', 'áspero', ','): 1,
#          ('amargo', 'e', 'áspero', ',', 'que'): 1,
#          ('e', 'áspero', ',', 'que', 'está'): 1,
#          ('áspero', ',', 'que', 'está', 'longe'): 1,
#          (',', 'que', 'está', 'longe', 'de'): 1,
#          ('que', 'está', 'longe', 'de', 'vir'): 1,
#          ('está', 'longe', 'de', 'vir', 'de'): 1,
#          ('longe', 'de', 'vir', 'de', 'seus'): 1,
#          ('de', 'vir', 'de', 'seus', 'modelos'): 1,
#          ('vir', 'de', 'seus', 'modelos', '.'): 1,
#          ('de', 'seus', 'modelos', '.', '</s>'): 1,
#          ('seus', 'modelos', '.', '</s>', '<s>'): 1,
#          ('modelos', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'É'): 17,
#          ('<s>', '<s>', '<s>', 'É', 'taça'): 1,
#          ('<s>', '<s>', 'É', 'taça', 'que'): 1,
#          ('<s>', 'É', 'taça', 'que', 'pode'): 1,
#          ('É', 'taça', 'que', 'pode', 'ter'): 1,
#          ('taça', 'que', 'pode', 'ter', 'lavores'): 1,
#          ('que', 'pode', 'ter', 'lavores', 'de'): 1,
#          ('pode', 'ter', 'lavores', 'de', 'igual'): 1,
#          ('ter', 'lavores', 'de', 'igual', 'escola'): 1,
#          ('lavores', 'de', 'igual', 'escola', ','): 1,
#          ('de', 'igual', 'escola', ',', 'mas'): 1,
#          ('igual', 'escola', ',', 'mas', 'leva'): 1,
#          ('escola', ',', 'mas', 'leva', 'outro'): 1,
#          (',', 'mas', 'leva', 'outro', 'vinho'): 1,
#          ('mas', 'leva', 'outro', 'vinho', '.'): 1,
#          ('leva', 'outro', 'vinho', '.', '</s>'): 1,
#          ('outro', 'vinho', '.', '</s>', '<s>'): 1,
#          ('vinho', '.', '</s>', '<s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', '<s>', 'Não'): 185,
#          ('<s>', '<s>', '<s>', 'Não', 'digo'): 10,
#          ('<s>', '<s>', 'Não', 'digo', 'mais'): 2,
#          ('<s>', 'Não', 'digo', 'mais', 'para'): 1,
#          ('Não', 'digo', 'mais', 'para', 'não'): 1,
#          ('digo', 'mais', 'para', 'não', 'entrar'): 1,
#          ('mais', 'para', 'não', 'entrar', 'na'): 1,
#          ('para', 'não', 'entrar', 'na', 'crítica'): 1,
#          ('não', 'entrar', 'na', 'crítica', 'de'): 1,
#          ('entrar', 'na', 'crítica', 'de', 'um'): 1,
#          ('na', 'crítica', 'de', 'um', 'defunto'): 1,
#          ('crítica', 'de', 'um', 'defunto', ','): 1,
#          ('de', 'um', 'defunto', ',', 'que'): 1,
#          ('um', 'defunto', ',', 'que', 'se'): 1,
#          ('defunto', ',', 'que', 'se', 'pintou'): 1,
#          (',', 'que', 'se', 'pintou', 'a'): 1,
#          ('que', 'se', 'pintou', 'a', 'si'): 1,
#          ('se', 'pintou', 'a', 'si', 'e'): 1,
#          ('pintou', 'a', 'si', 'e', 'a'): 1,
#          ('a', 'si', 'e', 'a', 'outros'): 1,
#          ('si', 'e', 'a', 'outros', ','): 1,
#          ('e', 'a', 'outros', ',', 'conforme'): 1,
#          ('a', 'outros', ',', 'conforme', 'lhe'): 1,
#          ('outros', ',', 'conforme', 'lhe', 'pareceu'): 1,
#          (',', 'conforme', 'lhe', 'pareceu', 'melhor'): 1,
#          ('conforme', 'lhe', 'pareceu', 'melhor', 'e'): 1,
#          ('lhe', 'pareceu', 'melhor', 'e', 'mais'): 1,
#          ('pareceu', 'melhor', 'e', 'mais', 'certo'): 1,
#          ('melhor', 'e', 'mais', 'certo', '.'): 1,
#          ('e', 'mais', 'certo', '.', '</s>'): 1,
#          ('mais', 'certo', '.', '</s>', '<s>'): 1,
#          ('certo', '.', '</s>', '<s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', '<s>', 'Machado'): 1,
#          ('<s>', '<s>', '<s>', 'Machado', 'de'): 1,
#          ('<s>', '<s>', 'Machado', 'de', 'Assis'): 1,
#          ('<s>', 'Machado', 'de', 'Assis', '.'): 1,
#          ('Machado', 'de', 'Assis', '.', '</s>'): 1,
#          ('de', 'Assis', '.', '</s>', '<s>'): 1,
#          ('Assis', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'AO'): 1,
#          ('<s>', '<s>', '<s>', 'AO', 'LEITOR'): 1,
#          ('<s>', '<s>', 'AO', 'LEITOR', '</s>'): 1,
#          ('<s>', 'AO', 'LEITOR', '</s>', '<s>'): 1,
#          ('AO', 'LEITOR', '</s>', '<s>', '<s>'): 1,
#          ('LEITOR', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Que'): 39,
#          ('<s>', '<s>', '<s>', 'Que', 'Stendhal'): 1,
#          ('<s>', '<s>', 'Que', 'Stendhal', 'confessasse'): 1,
#          ('<s>', 'Que', 'Stendhal', 'confessasse', 'haver'): 1,
#          ('Que', 'Stendhal', 'confessasse', 'haver', 'escrito'): 1,
#          ('Stendhal', 'confessasse', 'haver', 'escrito', 'um'): 1,
#          ('confessasse', 'haver', 'escrito', 'um', 'de'): 1,
#          ('haver', 'escrito', 'um', 'de', 'seus'): 1,
#          ('escrito', 'um', 'de', 'seus', 'livros'): 1,
#          ('um', 'de', 'seus', 'livros', 'para'): 1,
#          ('de', 'seus', 'livros', 'para', 'cem'): 1,
#          ('seus', 'livros', 'para', 'cem', 'leitores'): 1,
#          ('livros', 'para', 'cem', 'leitores', ','): 1,
#          ('para', 'cem', 'leitores', ',', 'coisa'): 1,
#          ('cem', 'leitores', ',', 'coisa', 'é'): 1,
#          ('leitores', ',', 'coisa', 'é', 'que'): 1,
#          (',', 'coisa', 'é', 'que', 'admira'): 1,
#          ('coisa', 'é', 'que', 'admira', 'e'): 1,
#          ('é', 'que', 'admira', 'e', 'consterna'): 1,
#          ('que', 'admira', 'e', 'consterna', '.'): 1,
#          ('admira', 'e', 'consterna', '.', '</s>'): 1,
#          ('e', 'consterna', '.', '</s>', '<s>'): 1,
#          ('consterna', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', 'O', 'que', 'não'): 2,
#          ('<s>', 'O', 'que', 'não', 'admira'): 1,
#          ('O', 'que', 'não', 'admira', ','): 1,
#          ('que', 'não', 'admira', ',', 'nem'): 1,
#          ('não', 'admira', ',', 'nem', 'provavelmente'): 1,
#          ('admira', ',', 'nem', 'provavelmente', 'consternará'): 1,
#          (',', 'nem', 'provavelmente', 'consternará', 'é'): 1,
#          ('nem', 'provavelmente', 'consternará', 'é', 'se'): 1,
#          ('provavelmente', 'consternará', 'é', 'se', 'este'): 1,
#          ('consternará', 'é', 'se', 'este', 'outro'): 1,
#          ('é', 'se', 'este', 'outro', 'livro'): 1,
#          ('se', 'este', 'outro', 'livro', 'não'): 1,
#          ('este', 'outro', 'livro', 'não', 'tiver'): 1,
#          ('outro', 'livro', 'não', 'tiver', 'os'): 1,
#          ('livro', 'não', 'tiver', 'os', 'cem'): 1,
#          ('não', 'tiver', 'os', 'cem', 'leitores'): 1,
#          ('tiver', 'os', 'cem', 'leitores', 'de'): 1,
#          ('os', 'cem', 'leitores', 'de', 'Stendhal'): 1,
#          ('cem', 'leitores', 'de', 'Stendhal', ','): 1,
#          ('leitores', 'de', 'Stendhal', ',', 'nem'): 1,
#          ('de', 'Stendhal', ',', 'nem', 'cinqüenta'): 1,
#          ('Stendhal', ',', 'nem', 'cinqüenta', ','): 1,
#          (',', 'nem', 'cinqüenta', ',', 'nem'): 1,
#          ('nem', 'cinqüenta', ',', 'nem', 'vinte'): 1,
#          ('cinqüenta', ',', 'nem', 'vinte', 'e'): 1,
#          (',', 'nem', 'vinte', 'e', ','): 1,
#          ('nem', 'vinte', 'e', ',', 'quando'): 1,
#          ('vinte', 'e', ',', 'quando', 'muito'): 1,
#          ('e', ',', 'quando', 'muito', ','): 1,
#          (',', 'quando', 'muito', ',', 'dez'): 1,
#          ('quando', 'muito', ',', 'dez', '.'): 1,
#          ('muito', ',', 'dez', '.', '</s>'): 1,
#          (',', 'dez', '.', '</s>', '<s>'): 1,
#          ('dez', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Dez'): 1,
#          ('<s>', '<s>', '<s>', 'Dez', '?'): 1,
#          ('<s>', '<s>', 'Dez', '?', '</s>'): 1,
#          ('<s>', 'Dez', '?', '</s>', '<s>'): 1,
#          ('Dez', '?', '</s>', '<s>', '<s>'): 1,
#          ('?', '</s>', '<s>', '<s>', '<s>'): 262,
#          ('<s>', '<s>', '<s>', '<s>', 'Talvez'): 30,
#          ('<s>', '<s>', '<s>', 'Talvez', 'cinco'): 2,
#          ('<s>', '<s>', 'Talvez', 'cinco', '.'): 1,
#          ('<s>', 'Talvez', 'cinco', '.', '</s>'): 1,
#          ('Talvez', 'cinco', '.', '</s>', '<s>'): 1,
#          ('cinco', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Trata'): 3,
#          ('<s>', '<s>', '<s>', 'Trata', '-'): 2,
#          ('<s>', '<s>', 'Trata', '-', 'se'): 1,
#          ('<s>', 'Trata', '-', 'se', ','): 1,
#          ('Trata', '-', 'se', ',', 'na'): 1,
#          ('-', 'se', ',', 'na', 'verdade'): 1,
#          ('se', ',', 'na', 'verdade', ','): 1,
#          (',', 'na', 'verdade', ',', 'de'): 1,
#          ('na', 'verdade', ',', 'de', 'uma'): 1,
#          ('verdade', ',', 'de', 'uma', 'obra'): 1,
#          (',', 'de', 'uma', 'obra', 'difusa'): 1,
#          ('livre', 'de', 'um', 'Sterne', ','): 1,
#          ('de', 'um', 'Sterne', ',', 'ou'): 1,
#          ('um', 'Sterne', ',', 'ou', 'de'): 1,
#          ('Sterne', ',', 'ou', 'de', 'um'): 1,
#          (',', 'ou', 'de', 'um', 'Xavier'): 1,
#          ('algumas', 'rabugens', 'de', 'pessimismo', '.'): 1,
#          ('rabugens', 'de', 'pessimismo', '.', '</s>'): 1,
#          ('de', 'pessimismo', '.', '</s>', '<s>'): 1,
#          ('pessimismo', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Pode'): 1,
#          ('<s>', '<s>', '<s>', 'Pode', 'ser'): 1,
#          ('<s>', '<s>', 'Pode', 'ser', '.'): 1,
#          ('<s>', 'Pode', 'ser', '.', '</s>'): 1,
#          ('Pode', 'ser', '.', '</s>', '<s>'): 2,
#          ('ser', '.', '</s>', '<s>', '<s>'): 4,
#          ('<s>', '<s>', '<s>', '<s>', 'Obra'): 1,
#          ('<s>', '<s>', '<s>', 'Obra', 'de'): 1,
#          ('<s>', '<s>', 'Obra', 'de', 'finado'): 1,
#          ('<s>', 'Obra', 'de', 'finado', '.'): 1,
#          ('Obra', 'de', 'finado', '.', '</s>'): 1,
#          ('de', 'finado', '.', '</s>', '<s>'): 1,
#          ('finado', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Escrevi'): 2,
#          ('<s>', '<s>', '<s>', 'Escrevi', '-'): 1,
#          ('<s>', '<s>', 'Escrevi', '-', 'a'): 1,
#          ('<s>', 'Escrevi', '-', 'a', 'com'): 1,
#          ('Escrevi', '-', 'a', 'com', 'a'): 1,
#          ('-', 'a', 'com', 'a', 'pena'): 1,
#          ('a', 'com', 'a', 'pena', 'da'): 1,
#          ('com', 'a', 'pena', 'da', 'galhofa'): 1,
#          ('a', 'pena', 'da', 'galhofa', 'e'): 1,
#          ('pena', 'da', 'galhofa', 'e', 'a'): 1,
#          ('da', 'galhofa', 'e', 'a', 'tinta'): 1,
#          ('galhofa', 'e', 'a', 'tinta', 'da'): 1,
#          ('e', 'a', 'tinta', 'da', 'melancolia'): 1,
#          ('a', 'tinta', 'da', 'melancolia', ','): 1,
#          ('tinta', 'da', 'melancolia', ',', 'e'): 1,
#          ('da', 'melancolia', ',', 'e', 'não'): 1,
#          ('melancolia', ',', 'e', 'não', 'é'): 1,
#          (',', 'e', 'não', 'é', 'difícil'): 1,
#          ('e', 'não', 'é', 'difícil', 'antever'): 1,
#          ('não', 'é', 'difícil', 'antever', 'o'): 1,
#          ('é', 'difícil', 'antever', 'o', 'que'): 1,
#          ('difícil', 'antever', 'o', 'que', 'poderá'): 1,
#          ('antever', 'o', 'que', 'poderá', 'sair'): 1,
#          ('o', 'que', 'poderá', 'sair', 'desse'): 1,
#          ('que', 'poderá', 'sair', 'desse', 'conúbio'): 1,
#          ('poderá', 'sair', 'desse', 'conúbio', '.'): 1,
#          ('sair', 'desse', 'conúbio', '.', '</s>'): 1,
#          ('desse', 'conúbio', '.', '</s>', '<s>'): 1,
#          ('conúbio', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Acresce'): 3,
#          ('<s>', '<s>', '<s>', 'Acresce', 'que'): 3,
#          ('<s>', '<s>', 'Acresce', 'que', 'a'): 1,
#          ('<s>', 'Acresce', 'que', 'a', 'gente'): 1,
#          ('Acresce', 'que', 'a', 'gente', 'grave'): 1,
#          ('que', 'a', 'gente', 'grave', 'achará'): 1,
#          ('a', 'gente', 'grave', 'achará', 'no'): 1,
#          ('gente', 'grave', 'achará', 'no', 'livro'): 1,
#          ('grave', 'achará', 'no', 'livro', 'umas'): 1,
#          ('achará', 'no', 'livro', 'umas', 'aparências'): 1,
#          ('no', 'livro', 'umas', 'aparências', 'de'): 1,
#          ('livro', 'umas', 'aparências', 'de', 'puro'): 1,
#          ('umas', 'aparências', 'de', 'puro', 'romance'): 1,
#          ('aparências', 'de', 'puro', 'romance', ','): 1,
#          ('de', 'puro', 'romance', ',', 'ao'): 1,
#          ('puro', 'romance', ',', 'ao', 'passo'): 1,
#          ('romance', ',', 'ao', 'passo', 'que'): 1,
#          (',', 'ao', 'passo', 'que', 'a'): 3,
#          ('ao', 'passo', 'que', 'a', 'gente'): 1,
#          ('passo', 'que', 'a', 'gente', 'frívola'): 1,
#          ('que', 'a', 'gente', 'frívola', 'não'): 1,
#          ('a', 'gente', 'frívola', 'não', 'achará'): 1,
#          ('gente', 'frívola', 'não', 'achará', 'nele'): 1,
#          ('frívola', 'não', 'achará', 'nele', 'o'): 1,
#          ('não', 'achará', 'nele', 'o', 'seu'): 1,
#          ('achará', 'nele', 'o', 'seu', 'romance'): 1,
#          ('nele', 'o', 'seu', 'romance', 'usual'): 1,
#          ('o', 'seu', 'romance', 'usual', ';'): 1,
#          ('seu', 'romance', 'usual', ';', 'ei'): 1,
#          ('romance', 'usual', ';', 'ei', '-'): 1,
#          ('usual', ';', 'ei', '-', 'lo'): 1,
#          (';', 'ei', '-', 'lo', 'aí'): 1,
#          ('ei', '-', 'lo', 'aí', 'fica'): 1,
#          ('-', 'lo', 'aí', 'fica', 'privado'): 1,
#          ('lo', 'aí', 'fica', 'privado', 'da'): 1,
#          ('aí', 'fica', 'privado', 'da', 'estima'): 1,
#          ('fica', 'privado', 'da', 'estima', 'dos'): 1,
#          ('privado', 'da', 'estima', 'dos', 'graves'): 1,
#          ('da', 'estima', 'dos', 'graves', 'e'): 1,
#          ('estima', 'dos', 'graves', 'e', 'do'): 1,
#          ('dos', 'graves', 'e', 'do', 'amor'): 1,
#          ('graves', 'e', 'do', 'amor', 'dos'): 1,
#          ('e', 'do', 'amor', 'dos', 'frívolos'): 1,
#          ('do', 'amor', 'dos', 'frívolos', ','): 1,
#          ('amor', 'dos', 'frívolos', ',', 'que'): 1,
#          ('dos', 'frívolos', ',', 'que', 'são'): 1,
#          ('frívolos', ',', 'que', 'são', 'as'): 1,
#          (',', 'que', 'são', 'as', 'duas'): 1,
#          ('que', 'são', 'as', 'duas', 'colunas'): 1,
#          ('são', 'as', 'duas', 'colunas', 'máximas'): 1,
#          ('as', 'duas', 'colunas', 'máximas', 'da'): 1,
#          ('duas', 'colunas', 'máximas', 'da', 'opinião'): 1,
#          ('colunas', 'máximas', 'da', 'opinião', '.'): 1,
#          ('máximas', 'da', 'opinião', '.', '</s>'): 1,
#          ('da', 'opinião', '.', '</s>', '<s>'): 2,
#          ('opinião', '.', '</s>', '<s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', '<s>', 'Mas'): 68,
#          ('<s>', '<s>', '<s>', 'Mas', 'eu'): 10,
#          ('<s>', '<s>', 'Mas', 'eu', 'ainda'): 1,
#          ('<s>', 'Mas', 'eu', 'ainda', 'espero'): 1,
#          ('Mas', 'eu', 'ainda', 'espero', 'angariar'): 1,
#          ('eu', 'ainda', 'espero', 'angariar', 'as'): 1,
#          ('ainda', 'espero', 'angariar', 'as', 'simpatias'): 1,
#          ('espero', 'angariar', 'as', 'simpatias', 'da'): 1,
#          ('angariar', 'as', 'simpatias', 'da', 'opinião'): 1,
#          ('as', 'simpatias', 'da', 'opinião', ','): 1,
#          ('simpatias', 'da', 'opinião', ',', 'e'): 1,
#          ('da', 'opinião', ',', 'e', 'o'): 1,
#          ('opinião', ',', 'e', 'o', 'primeiro'): 1,
#          (',', 'e', 'o', 'primeiro', 'remédio'): 1,
#          ('e', 'o', 'primeiro', 'remédio', 'é'): 1,
#          ('o', 'primeiro', 'remédio', 'é', 'fugir'): 1,
#          ('primeiro', 'remédio', 'é', 'fugir', 'a'): 1,
#          ('remédio', 'é', 'fugir', 'a', 'um'): 1,
#          ('é', 'fugir', 'a', 'um', 'prólogo'): 1,
#          ('fugir', 'a', 'um', 'prólogo', 'explícito'): 1,
#          ('a', 'um', 'prólogo', 'explícito', 'e'): 1,
#          ('um', 'prólogo', 'explícito', 'e', 'longo'): 1,
#          ('prólogo', 'explícito', 'e', 'longo', '.'): 1,
#          ('explícito', 'e', 'longo', '.', '</s>'): 1,
#          ('e', 'longo', '.', '</s>', '<s>'): 2,
#          ('longo', '.', '</s>', '<s>', '<s>'): 3,
#          ('<s>', '<s>', '<s>', 'O', 'melhor'): 4,
#          ('<s>', '<s>', 'O', 'melhor', 'prólogo'): 1,
#          ('<s>', 'O', 'melhor', 'prólogo', 'é'): 1,
#          ('O', 'melhor', 'prólogo', 'é', 'o'): 1,
#          ('melhor', 'prólogo', 'é', 'o', 'que'): 1,
#          ('prólogo', 'é', 'o', 'que', 'contém'): 1,
#          ('é', 'o', 'que', 'contém', 'menos'): 1,
#          ('o', 'que', 'contém', 'menos', 'coisas'): 1,
#          ('que', 'contém', 'menos', 'coisas', ','): 1,
#          ('contém', 'menos', 'coisas', ',', 'ou'): 1,
#          ('menos', 'coisas', ',', 'ou', 'o'): 1,
#          ('coisas', ',', 'ou', 'o', 'que'): 1,
#          (',', 'ou', 'o', 'que', 'as'): 1,
#          ('ou', 'o', 'que', 'as', 'diz'): 1,
#          ('o', 'que', 'as', 'diz', 'de'): 1,
#          ('que', 'as', 'diz', 'de', 'um'): 1,
#          ('as', 'diz', 'de', 'um', 'jeito'): 1,
#          ('diz', 'de', 'um', 'jeito', 'obscuro'): 1,
#          ('de', 'um', 'jeito', 'obscuro', 'e'): 1,
#          ('um', 'jeito', 'obscuro', 'e', 'truncado'): 1,
#          ('jeito', 'obscuro', 'e', 'truncado', '.'): 1,
#          ('obscuro', 'e', 'truncado', '.', '</s>'): 1,
#          ('e', 'truncado', '.', '</s>', '<s>'): 1,
#          ('truncado', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Conseguintemente'): 1,
#          ('<s>', '<s>', '<s>', 'Conseguintemente', ','): 1,
#          ('<s>', '<s>', 'Conseguintemente', ',', 'evito'): 1,
#          ('<s>', 'Conseguintemente', ',', 'evito', 'contar'): 1,
#          ('Conseguintemente', ',', 'evito', 'contar', 'o'): 1,
#          (',', 'evito', 'contar', 'o', 'processo'): 1,
#          ('evito', 'contar', 'o', 'processo', 'extraordinário'): 1,
#          ('contar', 'o', 'processo', 'extraordinário', 'que'): 1,
#          ('o', 'processo', 'extraordinário', 'que', 'empreguei'): 1,
#          ('processo', 'extraordinário', 'que', 'empreguei', 'na'): 1,
#          ('extraordinário', 'que', 'empreguei', 'na', 'composição'): 1,
#          ('que', 'empreguei', 'na', 'composição', 'destas'): 1,
#          ('empreguei', 'na', 'composição', 'destas', 'Memórias'): 1,
#          ('na', 'composição', 'destas', 'Memórias', ','): 1,
#          ('composição', 'destas', 'Memórias', ',', 'trabalhadas'): 1,
#          ('destas', 'Memórias', ',', 'trabalhadas', 'cá'): 1,
#          ('Memórias', ',', 'trabalhadas', 'cá', 'no'): 1,
#          (',', 'trabalhadas', 'cá', 'no', 'outro'): 1,
#          ('trabalhadas', 'cá', 'no', 'outro', 'mundo'): 1,
#          ('cá', 'no', 'outro', 'mundo', '.'): 1,
#          ('no', 'outro', 'mundo', '.', '</s>'): 1,
#          ('outro', 'mundo', '.', '</s>', '<s>'): 1,
#          ('mundo', '.', '</s>', '<s>', '<s>'): 3,
#          ('<s>', '<s>', '<s>', '<s>', 'Seria'): 3,
#          ('<s>', '<s>', '<s>', 'Seria', 'curioso'): 1,
#          ('<s>', '<s>', 'Seria', 'curioso', ','): 1,
#          ('<s>', 'Seria', 'curioso', ',', 'mas'): 1,
#          ('Seria', 'curioso', ',', 'mas', 'nimiamente'): 1,
#          ('curioso', ',', 'mas', 'nimiamente', 'extenso'): 1,
#          (',', 'mas', 'nimiamente', 'extenso', ','): 1,
#          ('mas', 'nimiamente', 'extenso', ',', 'e'): 1,
#          ('nimiamente', 'extenso', ',', 'e', 'aliás'): 1,
#          ('extenso', ',', 'e', 'aliás', 'desnecessário'): 1,
#          (',', 'e', 'aliás', 'desnecessário', 'ao'): 1,
#          ('e', 'aliás', 'desnecessário', 'ao', 'entendimento'): 1,
#          ('aliás', 'desnecessário', 'ao', 'entendimento', 'da'): 1,
#          ('desnecessário', 'ao', 'entendimento', 'da', 'obra'): 1,
#          ('ao', 'entendimento', 'da', 'obra', '.'): 1,
#          ('entendimento', 'da', 'obra', '.', '</s>'): 1,
#          ('da', 'obra', '.', '</s>', '<s>'): 1,
#          ('obra', '.', '</s>', '<s>', '<s>'): 2,
#          ('<s>', '<s>', '<s>', 'A', 'obra'): 1,
#          ('<s>', '<s>', 'A', 'obra', 'em'): 1,
#          ('<s>', 'A', 'obra', 'em', 'si'): 1,
#          ('A', 'obra', 'em', 'si', 'mesma'): 1,
#          ('obra', 'em', 'si', 'mesma', 'é'): 1,
#          ('em', 'si', 'mesma', 'é', 'tudo'): 1,
#          ('si', 'mesma', 'é', 'tudo', ':'): 1,
#          ('mesma', 'é', 'tudo', ':', 'se'): 1,
#          ('é', 'tudo', ':', 'se', 'te'): 1,
#          ('tudo', ':', 'se', 'te', 'agradar'): 1,
#          (':', 'se', 'te', 'agradar', ','): 1,
#          ('se', 'te', 'agradar', ',', 'fino'): 1,
#          ('te', 'agradar', ',', 'fino', 'leitor'): 1,
#          ('agradar', ',', 'fino', 'leitor', ','): 1,
#          (',', 'fino', 'leitor', ',', 'pago'): 1,
#          ('fino', 'leitor', ',', 'pago', '-'): 1,
#          ('leitor', ',', 'pago', '-', 'me'): 1,
#          (',', 'pago', '-', 'me', 'da'): 1,
#          ('pago', '-', 'me', 'da', 'tarefa'): 1,
#          ('-', 'me', 'da', 'tarefa', ';'): 1,
#          ('me', 'da', 'tarefa', ';', 'se'): 1,
#          ('da', 'tarefa', ';', 'se', 'te'): 1,
#          ('tarefa', ';', 'se', 'te', 'não'): 1,
#          (';', 'se', 'te', 'não', 'agradar'): 1,
#          ('se', 'te', 'não', 'agradar', ','): 1,
#          ('te', 'não', 'agradar', ',', 'pago'): 1,
#          ('não', 'agradar', ',', 'pago', '-'): 1,
#          ('agradar', ',', 'pago', '-', 'te'): 1,
#          (',', 'pago', '-', 'te', 'com'): 1,
#          ('pago', '-', 'te', 'com', 'um'): 1,
#          ('-', 'te', 'com', 'um', 'piparote'): 1,
#          ('te', 'com', 'um', 'piparote', ','): 1,
#          ('com', 'um', 'piparote', ',', 'e'): 1,
#          ('um', 'piparote', ',', 'e', 'adeus'): 1,
#          ('piparote', ',', 'e', 'adeus', '.'): 1,
#          (',', 'e', 'adeus', '.', '</s>'): 1,
#          ('e', 'adeus', '.', '</s>', '<s>'): 1,
#          ('adeus', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Brás'): 1,
#          ('<s>', '<s>', '<s>', 'Brás', 'Cubas'): 1,
#          ('<s>', '<s>', 'Brás', 'Cubas', '.'): 1,
#          ('<s>', 'Brás', 'Cubas', '.', '</s>'): 1,
#          ('Brás', 'Cubas', '.', '</s>', '<s>'): 6,
#          ('Cubas', '.', '</s>', '<s>', '<s>'): 8,
#          ('<s>', '<s>', '<s>', '<s>', 'CAPÍTULO'): 160,
#          ('<s>', '<s>', '<s>', 'CAPÍTULO', 'PRIMEIRO'): 1,
#          ('<s>', '<s>', 'CAPÍTULO', 'PRIMEIRO', '/'): 1,
#          ('<s>', 'CAPÍTULO', 'PRIMEIRO', '/', 'ÓBITO'): 1,
#          ('CAPÍTULO', 'PRIMEIRO', '/', 'ÓBITO', 'DO'): 1,
#          ('PRIMEIRO', '/', 'ÓBITO', 'DO', 'AUTOR'): 1,
#          ('/', 'ÓBITO', 'DO', 'AUTOR', '</s>'): 1,
#          ('ÓBITO', 'DO', 'AUTOR', '</s>', '<s>'): 1,
#          ('DO', 'AUTOR', '</s>', '<s>', '<s>'): 1,
#          ('AUTOR', '</s>', '<s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Algum'): 3,
#          ('<s>', '<s>', '<s>', 'Algum', 'tempo'): 2,
#          ('<s>', '<s>', 'Algum', 'tempo', 'hesitei'): 1,
#          ('<s>', 'Algum', 'tempo', 'hesitei', 'se'): 1,
#          ('Algum', 'tempo', 'hesitei', 'se', 'devia'): 1,
#          ('tempo', 'hesitei', 'se', 'devia', 'abrir'): 1,
#          ('hesitei', 'se', 'devia', 'abrir', 'estas'): 1,
#          ('se', 'devia', 'abrir', 'estas', 'memórias'): 1,
#          ('devia', 'abrir', 'estas', 'memórias', 'pelo'): 1,
#          ('abrir', 'estas', 'memórias', 'pelo', 'princípio'): 1,
#          ('estas', 'memórias', 'pelo', 'princípio', 'ou'): 1,
#          ('memórias', 'pelo', 'princípio', 'ou', 'pelo'): 1,
#          ('pelo', 'princípio', 'ou', 'pelo', 'fim'): 1,
#          ('princípio', 'ou', 'pelo', 'fim', ','): 1,
#          ('ou', 'pelo', 'fim', ',', 'isto'): 1,
#          ('pelo', 'fim', ',', 'isto', 'é'): 1,
#          ('fim', ',', 'isto', 'é', ','): 1,
#          (',', 'isto', 'é', ',', 'se'): 1,
#          ('isto', 'é', ',', 'se', 'poria'): 1,
#          ('é', ',', 'se', 'poria', 'em'): 1,
#          (',', 'se', 'poria', 'em', 'primeiro'): 1,
#          ('se', 'poria', 'em', 'primeiro', 'lugar'): 1,
#          ('poria', 'em', 'primeiro', 'lugar', 'o'): 1,
#          ('em', 'primeiro', 'lugar', 'o', 'meu'): 1,
#          ('primeiro', 'lugar', 'o', 'meu', 'nascimento'): 1,
#          ('lugar', 'o', 'meu', 'nascimento', 'ou'): 1,
#          ('o', 'meu', 'nascimento', 'ou', 'a'): 1,
#          ('meu', 'nascimento', 'ou', 'a', 'minha'): 1,
#          ('nascimento', 'ou', 'a', 'minha', 'morte'): 1,
#          ('ou', 'a', 'minha', 'morte', '.'): 1,
#          ('a', 'minha', 'morte', '.', '</s>'): 1,
#          ('minha', 'morte', '.', '</s>', '<s>'): 1,
#          ('morte', '.', '</s>', '<s>', '<s>'): 8,
#          ('<s>', '<s>', '<s>', '<s>', 'Suposto'): 1,
#          ('<s>', '<s>', '<s>', 'Suposto', 'o'): 1,
#          ('<s>', '<s>', 'Suposto', 'o', 'uso'): 1,
#          ('<s>', 'Suposto', 'o', 'uso', 'vulgar'): 1,
#          ('Suposto', 'o', 'uso', 'vulgar', 'seja'): 1,
#          ('o', 'uso', 'vulgar', 'seja', 'começar'): 1,
#          ('uso', 'vulgar', 'seja', 'começar', 'pelo'): 1,
#          ('vulgar', 'seja', 'começar', 'pelo', 'nascimento'): 1,
#          ('seja', 'começar', 'pelo', 'nascimento', ','): 1,
#          ('começar', 'pelo', 'nascimento', ',', 'duas'): 1,
#          ('pelo', 'nascimento', ',', 'duas', 'considerações'): 1,
#          ('nascimento', ',', 'duas', 'considerações', 'me'): 1,
#          (',', 'duas', 'considerações', 'me', 'levaram'): 1,
#          ('duas', 'considerações', 'me', 'levaram', 'a'): 1,
#          ('considerações', 'me', 'levaram', 'a', 'adotar'): 1,
#          ('me', 'levaram', 'a', 'adotar', 'diferente'): 1,
#          ('levaram', 'a', 'adotar', 'diferente', 'método'): 1,
#          ('a', 'adotar', 'diferente', 'método', ':'): 1,
#          ('adotar', 'diferente', 'método', ':', 'a'): 1,
#          ('diferente', 'método', ':', 'a', 'primeira'): 1,
#          ('método', ':', 'a', 'primeira', 'é'): 1,
#          (':', 'a', 'primeira', 'é', 'que'): 1,
#          ('a', 'primeira', 'é', 'que', 'eu'): 1,
#          ('primeira', 'é', 'que', 'eu', 'não'): 1,
#          ('é', 'que', 'eu', 'não', 'sou'): 1,
#          ('que', 'eu', 'não', 'sou', 'propriamente'): 1,
#          ('eu', 'não', 'sou', 'propriamente', 'um'): 1,
#          ('não', 'sou', 'propriamente', 'um', 'autor'): 1,
#          ('sou', 'propriamente', 'um', 'autor', 'defunto'): 1,
#          ('propriamente', 'um', 'autor', 'defunto', ','): 1,
#          ('um', 'autor', 'defunto', ',', 'mas'): 1,
#          ('autor', 'defunto', ',', 'mas', 'um'): 1,
#          ('defunto', ',', 'mas', 'um', 'defunto'): 1,
#          (',', 'mas', 'um', 'defunto', 'autor'): 1,
#          ('mas', 'um', 'defunto', 'autor', ','): 1,
#          ('um', 'defunto', 'autor', ',', 'para'): 1,
#          ('defunto', 'autor', ',', 'para', 'quem'): 1,
#          ('autor', ',', 'para', 'quem', 'a'): 1,
#          (',', 'para', 'quem', 'a', 'campa'): 1,
#          ('para', 'quem', 'a', 'campa', 'foi'): 1,
#          ('quem', 'a', 'campa', 'foi', 'outro'): 1,
#          ('a', 'campa', 'foi', 'outro', 'berço'): 1,
#          ('campa', 'foi', 'outro', 'berço', ';'): 1,
#          ('foi', 'outro', 'berço', ';', 'a'): 1,
#          ('outro', 'berço', ';', 'a', 'segunda'): 1,
#          ('berço', ';', 'a', 'segunda', 'é'): 1,
#          (';', 'a', 'segunda', 'é', 'que'): 1,
#          ('a', 'segunda', 'é', 'que', 'o'): 1,
#          ('segunda', 'é', 'que', 'o', 'escrito'): 1,
#          ('é', 'que', 'o', 'escrito', 'ficaria'): 1,
#          ('que', 'o', 'escrito', 'ficaria', 'assim'): 1,
#          ('o', 'escrito', 'ficaria', 'assim', 'mais'): 1,
#          ('escrito', 'ficaria', 'assim', 'mais', 'galante'): 1,
#          ('ficaria', 'assim', 'mais', 'galante', 'e'): 1,
#          ('assim', 'mais', 'galante', 'e', 'mais'): 1,
#          ('mais', 'galante', 'e', 'mais', 'novo'): 1,
#          ('galante', 'e', 'mais', 'novo', '.'): 1,
#          ('e', 'mais', 'novo', '.', '</s>'): 1,
#          ('mais', 'novo', '.', '</s>', '<s>'): 1,
#          ('novo', '.', '</s>', '<s>', '<s>'): 3,
#          ('<s>', '<s>', '<s>', '<s>', 'Moisés'): 1,
#          ('<s>', '<s>', '<s>', 'Moisés', ','): 1,
#          ('<s>', '<s>', 'Moisés', ',', 'que'): 1,
#          ('<s>', 'Moisés', ',', 'que', 'também'): 1,
#          ('Moisés', ',', 'que', 'também', 'contou'): 1,
#          (',', 'que', 'também', 'contou', 'a'): 1,
#          ('que', 'também', 'contou', 'a', 'sua'): 1,
#          ('também', 'contou', 'a', 'sua', 'morte'): 1,
#          ('contou', 'a', 'sua', 'morte', ','): 1,
#          ('a', 'sua', 'morte', ',', 'não'): 1,
#          ('sua', 'morte', ',', 'não', 'a'): 1,
#          ('morte', ',', 'não', 'a', 'pôs'): 1,
#          (',', 'não', 'a', 'pôs', 'no'): 1,
#          ('não', 'a', 'pôs', 'no', 'intróito'): 1,
#          ('a', 'pôs', 'no', 'intróito', ','): 1,
#          ('pôs', 'no', 'intróito', ',', 'mas'): 1,
#          ('no', 'intróito', ',', 'mas', 'no'): 1,
#          ('intróito', ',', 'mas', 'no', 'cabo'): 1,
#          (',', 'mas', 'no', 'cabo', ':'): 1,
#          ('mas', 'no', 'cabo', ':', 'diferença'): 1,
#          ('no', 'cabo', ':', 'diferença', 'radical'): 1,
#          ('cabo', ':', 'diferença', 'radical', 'entre'): 1,
#          (':', 'diferença', 'radical', 'entre', 'este'): 1,
#          ('diferença', 'radical', 'entre', 'este', 'livro'): 1,
#          ('radical', 'entre', 'este', 'livro', 'e'): 1,
#          ('entre', 'este', 'livro', 'e', 'o'): 1,
#          ('este', 'livro', 'e', 'o', 'Pentateuco'): 1,
#          ('livro', 'e', 'o', 'Pentateuco', '.'): 1,
#          ('e', 'o', 'Pentateuco', '.', '</s>'): 1,
#          ('o', 'Pentateuco', '.', '</s>', '<s>'): 1,
#          ('Pentateuco', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Dito'): 3,
#          ('<s>', '<s>', '<s>', 'Dito', 'isto'): 2,
#          ('<s>', '<s>', 'Dito', 'isto', ','): 2,
#          ('<s>', 'Dito', 'isto', ',', 'expirei'): 1,
#          ('Dito', 'isto', ',', 'expirei', 'às'): 1,
#          ('isto', ',', 'expirei', 'às', 'duas'): 1,
#          (',', 'expirei', 'às', 'duas', 'horas'): 1,
#          ('expirei', 'às', 'duas', 'horas', 'da'): 1,
#          ('às', 'duas', 'horas', 'da', 'tarde'): 1,
#          ('duas', 'horas', 'da', 'tarde', 'de'): 1,
#          ('horas', 'da', 'tarde', 'de', 'uma'): 1,
#          ('da', 'tarde', 'de', 'uma', 'sexta'): 1,
#          ('tarde', 'de', 'uma', 'sexta', '-'): 1,
#          ('de', 'uma', 'sexta', '-', 'feira'): 1,
#          ('uma', 'sexta', '-', 'feira', 'do'): 1,
#          ('sexta', '-', 'feira', 'do', 'mês'): 1,
#          ('-', 'feira', 'do', 'mês', 'de'): 1,
#          ('feira', 'do', 'mês', 'de', 'agosto'): 1,
#          ('do', 'mês', 'de', 'agosto', 'de'): 1,
#          ('mês', 'de', 'agosto', 'de', '1869'): 1,
#          ('de', 'agosto', 'de', '1869', ','): 1,
#          ('agosto', 'de', '1869', ',', 'na'): 1,
#          ('de', '1869', ',', 'na', 'minha'): 1,
#          ('1869', ',', 'na', 'minha', 'bela'): 1,
#          (',', 'na', 'minha', 'bela', 'chácara'): 1,
#          ('na', 'minha', 'bela', 'chácara', 'de'): 1,
#          ('minha', 'bela', 'chácara', 'de', 'Catumbi'): 1,
#          ('bela', 'chácara', 'de', 'Catumbi', '.'): 1,
#          ('chácara', 'de', 'Catumbi', '.', '</s>'): 1,
#          ('de', 'Catumbi', '.', '</s>', '<s>'): 1,
#          ('Catumbi', '.', '</s>', '<s>', '<s>'): 1,
#          ('<s>', '<s>', '<s>', '<s>', 'Tinha'): 18,
#          ('<s>', '<s>', '<s>', 'Tinha', 'uns'): 1,
#          ('<s>', '<s>', 'Tinha', 'uns', 'sessenta'): 1,
#          ('<s>', 'Tinha', 'uns', 'sessenta', 'e'): 1,
#          ('Tinha', 'uns', 'sessenta', 'e', 'quatro'): 1,
#          ('uns', 'sessenta', 'e', 'quatro', 'anos'): 1,
#          ('sessenta', 'e', 'quatro', 'anos', ','): 2,
#          ('e', 'quatro', 'anos', ',', 'rijos'): 1,
#          ('quatro', 'anos', ',', 'rijos', 'e'): 1,
#          ('anos', ',', 'rijos', 'e', 'prósperos'): 1,
#          (',', 'rijos', 'e', 'prósperos', ','): 1,
#          ('rijos', 'e', 'prósperos', ',', 'era'): 1,
#          ('e', 'prósperos', ',', 'era', 'solteiro'): 1,
#          ('prósperos', ',', 'era', 'solteiro', ','): 1,
#          (',', 'era', 'solteiro', ',', 'possuía'): 1,
#          ('era', 'solteiro', ',', 'possuía', 'cerca'): 1,
#          ('solteiro', ',', 'possuía', 'cerca', 'de'): 1,
#          (',', 'possuía', 'cerca', 'de', 'trezentos'): 1,
#          ('possuía', 'cerca', 'de', 'trezentos', 'contos'): 1,
#          ('cerca', 'de', 'trezentos', 'contos', 'e'): 1,
#          ('de', 'trezentos', 'contos', 'e', 'fui'): 1,
#          ('trezentos', 'contos', 'e', 'fui', 'acompanhado'): 1,
#          ('contos', 'e', 'fui', 'acompanhado', 'ao'): 1,
#          ('e', 'fui', 'acompanhado', 'ao', 'cemitério'): 1,
#          ...})

# %%
forgram_key = list(count_forgram.keys())
fivegram_key = list(count_fivegram.keys())
list_forgram = []
list_lastword = []
list_probs = []

# %%
list_forgram = []
list_lastword = []
list_probs = []

for t in fivegram_key:
    key_bigram = (t[0], t[1])
    prob = count_fivegram[t] / count_bigram[key_bigram]
    list_forgram.append(key_bigram)
    list_lastword.append(t[2])
    list_probs.append(prob)

# %%
model_df = pd.DataFrame({'ngram': list_forgram, 'lastword': list_lastword, 'prob': list_probs})
model_df
# Out:
#                         ngram    lastword      prob
# 0                  (<s>, <s>)         <s>  0.000262
# 1                  (<s>, <s>)         <s>  0.000262
# 2                  (<s>, <s>)     Romance  0.000262
# 3              (<s>, Romance)           ,  1.000000
# 4                (Romance, ,)    Memórias  1.000000
# 5               (,, Memórias)    Póstumas  1.000000
# 6        (Memórias, Póstumas)          de  0.800000
# 7              (Póstumas, de)        Brás  0.250000
# 8                  (de, Brás)       Cubas  0.166667
# 9               (Brás, Cubas)           ,  0.034483
# 10                 (Cubas, ,)        1880  0.062500
# 11                  (,, 1880)        </s>  1.000000
# 12               (1880, </s>)         <s>  1.000000
# 13                (</s>, <s>)         <s>  1.000000
# 14                 (<s>, <s>)         <s>  0.000262
# 15                 (<s>, <s>)         <s>  0.000262
# 16                 (<s>, <s>)    Memórias  0.000262
# 17            (<s>, Memórias)    Póstumas  1.000000
# 18             (Póstumas, de)        Brás  0.250000
# 19                 (de, Brás)       Cubas  0.166667
# 20              (Brás, Cubas)        </s>  0.034483
# 21              (Cubas, </s>)         <s>  1.000000
# 22                 (<s>, <s>)         <s>  0.000262
# 23                 (<s>, <s>)         <s>  0.000262
# 24                 (<s>, <s>)       Texto  0.000262
# 25               (<s>, Texto)           -  1.000000
# 26                 (Texto, -)       fonte  1.000000
# 27                 (-, fonte)           :  1.000000
# 28                 (fonte, :)        Obra  1.000000
# 29                  (:, Obra)    Completa  1.000000
# ...                       ...         ...       ...
# 81689           (um, pequeno)       saldo  1.000000
# 81690        (pequeno, saldo)           ,  1.000000
# 81691              (saldo, ,)         que  1.000000
# 81692                (,, que)           é  0.002242
# 81693                (que, é)           a  0.017241
# 81694                  (é, a)  derradeira  0.026316
# 81695         (a, derradeira)    negativa  1.000000
# 81696  (derradeira, negativa)       deste  1.000000
# 81697       (negativa, deste)    capítulo  1.000000
# 81698       (deste, capítulo)          de  1.000000
# 81699          (capítulo, de)   negativas  0.500000
# 81700         (de, negativas)           :  0.500000
# 81701          (negativas, :)             1.000000
# 81702                  (:, )         Não  0.031250
# 81703                (, Não)        tive  0.016393
# 81704             (Não, tive)      filhos  0.500000
# 81705          (tive, filhos)           ,  1.000000
# 81706             (filhos, ,)         não  0.250000
# 81707                (,, não)   transmiti  0.005682
# 81708        (não, transmiti)           a  1.000000
# 81709          (transmiti, a)     nenhuma  1.000000
# 81710            (a, nenhuma)    criatura  1.000000
# 81711     (nenhuma, criatura)           o  1.000000
# 81712           (criatura, o)      legado  1.000000
# 81713             (o, legado)          da  1.000000
# 81714            (legado, da)       nossa  1.000000
# 81715             (da, nossa)     miséria  0.071429
# 81716        (nossa, miséria)           .  1.000000
# 81717              (<s>, <s>)         <s>  0.000262
# 81718              (<s>, <s>)         <s>  0.000262
#
# [81719 rows x 3 columns]

# %%
bigram_df = model_df.loc[model_df['ngram'] == ('Memórias', 'Póstumas')]
bigram_df
# Out:
#                    ngram lastword  prob
# 6   (Memórias, Póstumas)       de   0.8
# 94  (Memórias, Póstumas)     </s>   0.2

# %%
num_sents = 50
current_bigram = ('<s>', '<s>')
i = 0
while i < num_sents:
    df = model_df.loc[model_df['ngram'] == current_bigram]
    words = df['lastword'].values
    probs = df['prob'].values
    last_word = random.choices(words, probs)[0]
    
    current_bigram = (current_bigram[1], last_word)
    
    if last_word == '</s>':
        i+=1
    
    if last_word != '<s>' and last_word != '</s>':
        print(last_word, end=' ')
# Out:
# Perdoe - me o Dutra uma noite . Uma vida de D . Marcela como passou a noite , com o problema da vida particular uma cessação de movimento . O despropósito fez - me polidamente o refresco ; minha madrinha é a Excelentíssima Senhora D . Plácida acabaria como tantas outras criaturas humanas ; donde se poderia deduzir que o dito da rainha de Navarra , ocorre que , se não arrancarem de mim próprio ...  Menos um . Adeus ! Éramos dois rapazes , o pai ganhava apenas o necessário para endividar - se logo , à vista da notoriedade com que ele estremeceu e ficou . O que não hei de contá - lo e separamo - nos ? Unamos agora os pés , dão azo ao prazer de as impor aos outros , espiando pela rótula . Não esqueças que , de aflições que desabrochavam em alegria , segundo convinha a essa anônima , a qual é ainda a aliança do Damasceno , uma barafunda de coisas e cenas da meninice , buriladas na memória de quem o açucareiro ; e tudo escapava à compreensão do olhar humano , todos os motivos que levam o homem no meio do oceano ? Depois , como os orçamentos : melhor é a verdade é que não é de manteiga . Tive idéia de que ele escancarara as janelas todas deste longo tempo , acaso vos lembrais desse mestre cozinheiro do Hotel Pharoux .  Qual ! Mandou buscar um maço de notas de dez tostões por mês . acudiu ele , atribuir ao teu sangue , e acabava com esta carta ; ele não era na minha boa Marcela ; e não era mais do que remontar o pensamento , e não tinha nascido , e tomei tanto tártaro , tanto , tanto , que , na casinha da Gamboa , à cabeceira , saboreava a goles extensos a alegria que se amam há muito tempo ? Lobo Neves em casa de Marcela . perguntou Virgília . Era um erro , e prontamente travou de conversa comigo . A baronesa entrou daí a pouco rodeado dos apostadores , ao ver gente estranha . perguntei eu no fim de algum tempo ficamos a olhar para baixo ou para usar de uma barretina ninguém ainda conseguira tirar tantas idéias .  Meu padrinho ?  Algum temporal ? De todas porém a que se lhes tiram os olhos em que eu buscava saber , na faina , adoecendo e sarando , com os olhos fúlgidos , como aliás me cabia .  Sabe que morre . Entrei a desconfiar que não insistisse , disse o sujeito , que lhe substituiu os reumatismos e tosses . Valha - me o silêncio ; alguns achavam o meu companheiro de colégio , as belas imagens , os olhos estúpidos , a princípio : tinha nojo de si , e repetia - os , enlacei - os depois , encontrei Lobo Neves , nomeado presidente de província , a esperança , consolação dos homens . Mas a alegria que se chama glória até essa outra que se dá à alma dos doentes e dos uivos do furacão , a causa da minha Vênus Manca . Não era absurda esta hipótese ; a mãe , a arregaçar - lhes também que vínhamos da missa espiritual . O Damião perguntou muitas vezes ; a terceira , compeliam - me as costas ; mas quem não se lembrava de dar mate ao meu corpo : sensação forte , jucundo , supõe trazer em si , na noite das luminárias , logo depois do almoço . CAPÍTULO CXXXVIII / A CARTA ANÔNIMA Antes de ir consolar Virgília não pôde calar a sua religião era uma de suas tropas , que levava idéias a respeito da pequena , à tua vontade , uma robusta donzelona , que vi logo nele o vencido era o instinto da vaidade , e eu ficava  no patamar . Venham mais dez , e eu pudesse encontrar outro marido , e todavia é verdade ; juro aos séculos que continuavam a passar , velozes e turbulentos , as gravatas , e a morte , um botão de ouro de Danae , três diamantes grandes encastoados num pente de diamantes ; recuei , tornei a subir as escadas , e ao estômago com os olhos nela , perguntei quem era a imagem de um modo malicioso ; talvez queiras uma coisa a que não viu estarem os homens , levado por nenhum outro liame , que ficou sem resposta . Vem ; se a rir comigo da superstição das duas mulheres , e com razão ; eu fugi ao espetáculo , relembrou os versos , e que não deixava de lhe querer e muito sol ; ele é o que ela olhava só , mas pausado e trôpego como quem leva din ...
